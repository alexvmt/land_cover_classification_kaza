# %% [markdown]
# # Local AutoML training
#
# ### Ressources
# - https://github.com/automl/auto-sklearn/issues/1684
# - https://geemap.org/notebooks/46_local_rf_training/

# %% [markdown]
# ## Install auto-sklearn

# %%
# 1. uninstall all affected packages
# !pip uninstall -y Cython scipy pyparsing scikit_learn imbalanced-learn mlxtend yellowbrick
# Out:
# Found existing installation: Cython 3.0.6
# Uninstalling Cython-3.0.6:
#   Successfully uninstalled Cython-3.0.6
# Found existing installation: scipy 1.11.4
# Uninstalling scipy-1.11.4:
#   Successfully uninstalled scipy-1.11.4
# Found existing installation: pyparsing 3.1.1
# Uninstalling pyparsing-3.1.1:
#   Successfully uninstalled pyparsing-3.1.1
# Found existing installation: scikit-learn 1.2.2
# Uninstalling scikit-learn-1.2.2:
#   Successfully uninstalled scikit-learn-1.2.2
# Found existing installation: imbalanced-learn 0.10.1
# Uninstalling imbalanced-learn-0.10.1:
#   Successfully uninstalled imbalanced-learn-0.10.1
# Found existing installation: mlxtend 0.22.0
# Uninstalling mlxtend-0.22.0:
#   Successfully uninstalled mlxtend-0.22.0
# Found existing installation: yellowbrick 1.5
# Uninstalling yellowbrick-1.5:
#   Successfully uninstalled yellowbrick-1.5

# %%
# 2. install packages to be downgraded
# !pip install Cython==0.29.36 scipy==1.9 pyparsing==2.4
# Out:
# Collecting Cython==0.29.36
#   Downloading Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.1 MB/s eta 0:00:00
# Collecting scipy==1.9
#   Downloading scipy-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 8.9 MB/s eta 0:00:00
# Collecting pyparsing==2.4
#   Downloading pyparsing-2.4.0-py2.py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from scipy==1.9) (1.23.5)
# Installing collected packages: scipy, pyparsing, Cython
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.13 requires scikit-learn, which is not installed.
# librosa 0.10.1 requires scikit-learn>=0.20.0, which is not installed.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# sklearn-pandas 2.2.0 requires scikit-learn>=0.23.0, which is not installed.
# httplib2 0.22.0 requires pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2; python_version > "3.0", but you have pyparsing 2.4.0 which is incompatible.
# Successfully installed Cython-0.29.36 pyparsing-2.4.0 scipy-1.9.0

# %%
# 3. install older scikit-learn disregarding its dependencies
# !pip install scikit-learn==0.24.2 --no-build-isolation
# Out:
# Collecting scikit-learn==0.24.2
#   Downloading scikit-learn-0.24.2.tar.gz (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 23.1 MB/s eta 0:00:00
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (1.23.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (1.9.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (3.2.0)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (pyproject.toml) ... done
#   Created wheel for scikit-learn: filename=scikit_learn-0.24.2-cp310-cp310-linux_x86_64.whl size=22231938 sha256=9750422c7c73c5cc17493f08501690de16d3c34d35e36519035ae2b00b4cd3fe
#   Stored in directory: /root/.cache/pip/wheels/13/a4/68/4e78865652fa14db4a162b491e5138565f97646f9e1f2ab8cc
# Successfully built scikit-learn
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.16.0 requires scikit-learn>=1.2.2, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed scikit-learn-0.24.2

# %%
# 4. finally install auto-sklearn
# !pip install auto-sklearn
# Out:
# Collecting auto-sklearn
#   Downloading auto-sklearn-0.15.0.tar.gz (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 29.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (4.5.0)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from auto-sklearn) (1.7.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (1.9.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (1.3.2)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (0.24.2)
# Requirement already satisfied: dask>=2021.12 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (2023.8.1)
# Requirement already satisfied: distributed>=2012.12 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (2023.8.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (6.0.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (1.5.3)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/liac-arff/
# Collecting liac-arff (from auto-sklearn)
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (3.2.0)
# Collecting ConfigSpace<0.5,>=0.4.21 (from auto-sklearn)
#   Downloading ConfigSpace-0.4.21-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 27.6 MB/s eta 0:00:00
# Collecting pynisher<0.7,>=0.6.3 (from auto-sklearn)
#   Downloading pynisher-0.6.4.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyrfr<0.9,>=0.8.1 (from auto-sklearn)
#   Downloading pyrfr-0.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 87.7 MB/s eta 0:00:00
# Collecting smac<1.3,>=1.2 (from auto-sklearn)
#   Downloading smac-1.2.tar.gz (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 29.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (0.29.36)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (2.4.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (7.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (1.0.7)
# Requirement already satisfied: psutil>=5.7.2 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (6.3.2)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (2.0.7)
# Requirement already satisfied: zict>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->auto-sklearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->auto-sklearn) (2023.3.post1)
# Collecting emcee>=3.0.0 (from smac<1.3,>=1.2->auto-sklearn)
#   Downloading emcee-3.1.4-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2021.12->auto-sklearn) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed>=2012.12->auto-sklearn) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->auto-sklearn) (1.16.0)
# Building wheels for collected packages: auto-sklearn, pynisher, smac, liac-arff
#   Building wheel for auto-sklearn (pyproject.toml) ... done
#   Created wheel for auto-sklearn: filename=auto_sklearn-0.15.0-py3-none-any.whl size=6641936 sha256=f821d880b88617e5f1e4400f31d1d66bf79b18c1ecc3872b7fd8d63a74a839fa
#   Stored in directory: /root/.cache/pip/wheels/4d/0a/f9/8c1a06bcc36bc16b467b044b5bb03a90f92a5c5e6cd443414b
#   Building wheel for pynisher (setup.py) ... done
#   Created wheel for pynisher: filename=pynisher-0.6.4-py3-none-any.whl size=7026 sha256=9535e2da19a0e23605245370aa350081b351536d70e83842f303b9d60d8ba5bb
#   Stored in directory: /root/.cache/pip/wheels/90/7b/53/b21d6b41910f43c7f1557262e579598f83e75e44c659c1bcce
#   Building wheel for smac (setup.py) ... done
#   Created wheel for smac: filename=smac-1.2-py3-none-any.whl size=215906 sha256=c18589547f7b6969baec23e1ccff11a0fa1575fa484cdf6423042b172fcb21f0
#   Stored in directory: /root/.cache/pip/wheels/66/2e/d9/2db14bdfcdc36bf12e202b44201df03f194367fcfd85ce2778
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11716 sha256=78d8fa8d179caca5f889035eb0ff8af38ce1e70f6b1e76db4962ee6ac3503eff
#   Stored in directory: /root/.cache/pip/wheels/5d/2a/9c/3895d9617f8f49a0883ba686326d598e78a1c2f54fe3cae86d
# Successfully built auto-sklearn pynisher smac liac-arff
# Installing collected packages: pyrfr, pynisher, liac-arff, emcee, ConfigSpace, smac, auto-sklearn
# Successfully installed ConfigSpace-0.4.21 auto-sklearn-0.15.0 emcee-3.1.4 liac-arff-2.5.0 pynisher-0.6.4 pyrfr-0.8.3 smac-1.2

# %%
# 5. then, try loading the package repeatedly until trash in its dependencies are clean
#import autosklearn

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/land_cover_classification_kaza/automl
# Out:
# /content/drive/MyDrive/land_cover_classification_kaza/automl

# %% [markdown]
# ## Load train and test set

# %%
train = pd.read_csv('train.csv')
train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4553b4cf2a0d> in <cell line: 2>()
#       1 file_name = 'RND_Binga_1000.csv'
# ----> 2 df = pd.read_csv(file_name)
#
# NameError: name 'pd' is not defined

# %%
X_train = train.drop(['class', 'LC2023'], axis=1)
X_train

# %%
y_train = train['class']
y_train

# %%
test = pd.read_csv('test.csv')
test

# %%
X_test = test.drop(['class', 'LC2023'], axis=1)
X_test

# %%
y_test = test['class']
y_test

# %% [markdown]
# ## Use auto-sklearn to find the best model/ensemble

# %%
import autosklearn.classification
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#    'classifier': ['random_forest'],

# %%
automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=600,
    ensemble_kwargs = {'ensemble_size': 1},
    include = {
        'feature_preprocessor': ['no_preprocessing']
    },
    n_jobs=-1
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
automl.fit(X_train, y_train)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# AutoSklearnClassifier(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                       ensemble_kwargs={'ensemble_size': 1},
#                       include={'feature_preprocessor': ['no_preprocessing']},
#                       n_jobs=-1, per_run_time_limit=120,
#                       time_left_for_this_task=600)

# %%
y_pred = automl.predict(X_test)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
print(classification_report(y_test, y_pred))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#               precision    recall  f1-score   support
#
#            0       0.17      0.14      0.15        14
#            1       0.73      0.55      0.63        40
#            2       0.63      0.78      0.70        65
#            3       0.61      0.73      0.66        89
#            4       0.50      0.26      0.34        19
#            5       0.58      0.47      0.52        96
#            6       0.72      0.92      0.81        39
#            7       0.42      0.29      0.34        17
#
#     accuracy                           0.61       379
#    macro avg       0.54      0.52      0.52       379
# weighted avg       0.60      0.61      0.60       379

# %%
print('Accuracy: {:0.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Accuracy: 0.6095

# %%
print('Precision: {:0.4f}'.format(precision_score(y_test, y_pred, average='macro')))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Precision: 0.5448

# %%
print('Recall: {:0.4f}'.format(recall_score(y_test, y_pred, average='macro')))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Recall: 0.5196

# %%
print('F1-Score: {:0.4f}'.format(f1_score(y_test, y_pred, average='macro')))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# F1-Score: 0.5204

# %%
confusion_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# array([[ 2,  2,  6,  0,  0,  1,  3,  0],
#        [ 3, 22,  6,  0,  0,  0,  8,  1],
#        [ 7,  4, 51,  0,  0,  1,  1,  1],
#        [ 0,  0,  0, 65,  2, 19,  0,  3],
#        [ 0,  0,  1,  2,  5, 10,  0,  1],
#        [ 0,  1, 12, 35,  3, 45,  0,  0],
#        [ 0,  0,  2,  0,  0,  0, 36,  1],
#        [ 0,  1,  3,  5,  0,  1,  2,  5]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
sns.heatmap(confusion_matrix, annot=True)
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### AutoML

# %%
automl.leaderboard(ensemble_only=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#           rank  ensemble_weight           type      cost  duration
# model_id
# 11           1              1.0     libsvm_svc  0.386986  1.744319
# 57           2              0.0            qda  0.390411  1.515283
# 96           3              0.0     libsvm_svc  0.393836  1.861773
# 28           4              0.0     libsvm_svc  0.400685  2.135344
# 60           5              0.0     libsvm_svc  0.404110  2.734173
# ...        ...              ...            ...       ...       ...
# 93          96              0.0     libsvm_svc  0.863014  1.660507
# 48          97              0.0  decision_tree  0.876712  3.723091
# 32          98              0.0            sgd  0.921233  1.569993
# 81          99              0.0            mlp  0.934932  3.447126
# 100        100              0.0     libsvm_svc  0.948630  2.443639
#
# [100 rows x 5 columns]

# %%
automl.leaderboard(ensemble_only=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#           rank  ensemble_weight        type      cost  duration
# model_id
# 11           1              1.0  libsvm_svc  0.386986  1.744319

# %%
automl.get_models_with_weights()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [(1.0,
#   SimpleClassificationPipeline({'balancing:strategy': 'none', 'classifier:__choice__': 'libsvm_svc', 'data_preprocessor:__choice__': 'feature_type', 'feature_preprocessor:__choice__': 'no_preprocessing', 'classifier:libsvm_svc:C': 12923.91167672086, 'classifier:libsvm_svc:gamma': 0.028106748647672205, 'classifier:libsvm_svc:kernel': 'rbf', 'classifier:libsvm_svc:max_iter': -1, 'classifier:libsvm_svc:shrinking': 'False', 'classifier:libsvm_svc:tol': 2.0706197108771777e-05, 'data_preprocessor:feature_type:numerical_transformer:imputation:strategy': 'median', 'data_preprocessor:feature_type:numerical_transformer:rescaling:__choice__': 'minmax'},
#   dataset_properties={
#     'task': 2,
#     'sparse': False,
#     'multilabel': False,
#     'multiclass': True,
#     'target_type': 'classification',
#     'signed': False}))]

# %%
automl.show_models()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {11: {'model_id': 11,
#   'rank': 1,
#   'cost': 0.386986301369863,
#   'ensemble_weight': 1.0,
#   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x78d855c8f640>,
#   'balancing': Balancing(random_state=1),
#   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x78d855ab26b0>,
#   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x78d855ab1ed0>,
#   'sklearn_classifier': SVC(C=12923.91167672086, cache_size=1953.9635416666667,
#       gamma=0.028106748647672205, max_iter=-1.0, random_state=1, shrinking=False,
#       tol=2.0706197108771777e-05)}}

# %%
# get i from the output above
i = 5
rf_automl = automl.show_models()[i]['sklearn_classifier']
rf_automl
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# RandomForestClassifier(criterion='entropy', max_features=59, min_samples_leaf=3,
#                        min_samples_split=12, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)

# %% [markdown]
# ## Train best model using sklearn

# %%
# copy paste hyperparameters from above here
rf = ensemble.RandomForestClassifier(
    criterion='entropy', max_features=12, min_samples_leaf=3,
                       min_samples_split=12, n_estimators=512, n_jobs=1,
                       random_state=1, warm_start=True
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
rf.fit(X_train, y_train)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# RandomForestClassifier(criterion='entropy', max_features=12, min_samples_leaf=3,
#                        min_samples_split=12, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)

# %% [markdown]
# ## Convert a sklearn classifier object to a list of strings

# %%
import time
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# convert the estimator into a list of strings
# this function also works with the ensemble.ExtraTrees estimator
start_time = time.perf_counter()
trees = ml.rf_to_strings(rf, X_train.columns)
end_time = time.perf_counter()
run_time = round((end_time - start_time) / 60, 2)
print('Run time: {} minutes.'.format(run_time))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Run time: 1.51 minutes.

# %%
# print the first tree to see the result
print(trees[0])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 1) root 1256 9999 9999 (172.41384660187222)
#   2) B3 <= 1315.549988 1256 0.9985 1
#     4) B8 <= 2533.242798 757 0.9227 0
#       8) B8 <= 2210.166626 559 0.8423 0
#         16) B4 <= 1155.531250 212 0.6453 0
#           32) B4 <= 988.968750 57 0.0897 0
#             64) B3 <= 997.000000 15 0.0000 0 *
#             65) B3 > 997.000000 6 0.5917 0 *
#           33) B4 > 988.968750 36 0.0000 0 *
#         17) B4 > 1155.531250 212 0.6453 0
#           34) B2 <= 1315.803589 155 0.7617 0
#             68) B3 <= 1177.937500 141 0.7016 0
#               136) B3 <= 1117.525024 97 0.5723 0
#                 272) B3 <= 1108.150024 63 0.6898 0
#                   544) B8 <= 2137.902710 57 0.6072 0
#                     1088) B2 <= 1118.047607 17 0.0000 0 *
#                     1089) B2 > 1118.047607 43 0.4350 0
#                       2178) B8 <= 1954.375000 10 0.9852 0 *
#                       2179) B8 > 1954.375000 16 0.0000 0 *
#                   545) B8 > 2137.902710 57 0.6072 0
#                     1090) B8 <= 2159.229126 7 1.0000 0 *
#                     1091) B8 > 2159.229126 7 0.5665 0 *
#                 273) B3 > 1108.150024 6 0.9911 1 *
#               137) B3 > 1117.525024 97 0.5723 0
#                 274) B8 <= 2097.500000 34 0.2352 0
#                   548) B2 <= 1213.416687 7 0.0000 0 *
#                   549) B2 > 1213.416687 9 0.7642 0 *
#                 275) B8 > 2097.500000 18 0.0000 0 *
#             69) B3 > 1177.937500 141 0.7016 0
#               138) B3 <= 1182.500000 7 0.9544 1 *
#               228) B3 <= 1519.208313 7 0.6500 1 *
#               229) B3 > 1519.208313 7 0.0000 1 *
#             115) B4 > 2077.503906 42 0.7335 1
#               230) B3 <= 1563.892883 11 0.5665 1 *
#               231) B3 > 1563.892883 28 0.8196 1
#                 462) B8 <= 3173.035767 9 0.7219 1 *
#                 463) B8 > 3173.035767 8 1.0000 0 *
#         29) B3 > 1687.816711 115 0.4505 1
#           58) B2 <= 1689.208313 20 0.0000 1 *
#           59) B2 > 1689.208313 6 0.5917 1 *
#       15) B8 > 3284.375000 24 0.0000 1 *

# %%
print(trees[1])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 1) root 1258 9999 9999 (162.61947037511516)
#   2) B4 <= 1621.663452 1258 0.9991 0
#     4) B2 <= 1362.857117 701 0.8458 0
#       8) B4 <= 990.772736 35 0.0000 0 *
#       9) B4 > 990.772736 639 0.8094 0
#         18) B8 <= 2221.000000 604 0.8303 0
#           36) B2 <= 1202.854187 214 0.4912 0
#             72) B4 <= 1050.322937 10 0.0000 0 *
#             73) B4 > 1050.322937 122 0.3767 0
#               146) B8 <= 2016.033325 112 0.4006 0
#                 292) B8 <= 1959.910706 46 0.1914 0
#                   584) B8 <= 1871.500000 12 0.0000 0 *
#                   585) B8 > 1871.500000 35 0.2539 0
#                     1170) B8 <= 1950.750000 23 0.3451 0
#                       2340) B2 <= 1150.166687 11 0.0000 0 *
#                       2341) B2 > 1150.166687 6 0.6500 0 *
#                     1171) B8 > 1950.750000 6 0.5033 0 *
#                 293) B8 > 1959.910706 11 0.0000 0 *
#               147) B8 > 2016.033325 112 0.4006 0
#                 294) B4 <= 1070.090271 7 0.8813 0 *
#                 295) B4 > 1070.090271 66 0.5033 0
#                   590) B8 <= 2056.666748 7 0.7793 0 *
#                   591) B8 > 2056.666748 59 0.4426 0
#                     1182) B8 <= 2175.416626 52 0.3681 0
#                       2364) B8 <= 2138.791626 39 0.2864 0
#                         4728) B4 <= 1251.200012 12 0.5226 0 *
#                         4729) B4 > 1251.200012 26 0.3843 0
#                           9458) B3 <= 1101.511902 8 0.0000 0 *
#                           9459) B3 > 1101.511902 6 0.5033 0 *
#                       2365) B8 > 2138.791626 13 0.0000 0 *
#                     1183) B8 > 2175.416626 52 0.3681 0
#                       2366) B8 <= 2204.562500 6 0.8631 0 *
#                       2367) B8 > 2204.562500 7 0.3095 0 *
#           37) B2 > 1202.854187 214 0.4912 0
#             74) B2 <= 1323.775024 92 0.6167 0
#               148) B3 <= 1189.250000 85 0.6471 0
#                 296) B2 <= 1251.750000 56 0.4621 0
#                   592) B4 <= 1333.380981 42 0.5639 0
#                     1184) B2 <= 1244.055542 25 0.6666 0
#                       2368) B8 <= 2075.764893 11 0.9774 0 *
#                       2369) B8 > 2075.764893 8 0.0000 0 *
#                     1185) B2 > 1244.055542 6 0.3912 0 *
#                   593) B4 > 1333.380981 42 0.5639 0
#                     1186) B2 <= 1235.875000 6 0.5033 0 *
#                     1187) B2 > 1235.875000 11 0.0000 0 *
#                             20353) B2 > 1169.816711 11 0.0000 0 *
#                           10177) B2 > 1180.732117 10 0.6962 0 *
#                         5089) B4 > 1538.492065 6 1.0000 0 *
#                       2545) B2 > 1182.944397 14 0.0000 0 *
#                     1273) B2 > 1193.538452 129 0.7259 0
#                       2546) B3 <= 1247.125000 82 0.8265 0
#                         5092) B4 <= 1365.466675 76 0.7945 0
#                           10184) B8 <= 2419.916748 6 0.8113 1 *
#                           10185) B8 > 2419.916748 10 0.8113 0 *
#                         5093) B4 > 1365.466675 76 0.7945 0
#                           10186) B2 <= 1199.275024 8 0.9957 1 *
#                           10187) B2 > 1199.275024 60 0.7136 0
#                             20374) B4 <= 1437.625000 52 0.5917 0
#                               40748) B4 <= 1419.229187 7 0.4138 0 *
#                               40749) B4 > 1419.229187 7 0.9940 1 *
#                             20375) B4 > 1437.625000 52 0.5917 0
#                               40750) B8 <= 2407.500000 11 0.7871 0 *
#                               40751) B8 > 2407.500000 38 0.4091 0
#                                 81502) B4 <= 1555.633301 19 0.0000 0 *
#                                 81503) B4 > 1555.633301 8 0.3912 0 *
#                       2547) B3 > 1247.125000 6 0.9183 1 *
#                   637) B2 > 1258.366699 146 0.6832 0
#                     1274) B2 <= 1272.011902 11 0.2499 0 *
#                     1275) B2 > 1272.011902 6 0.4690 0 *
#                 319) B2 > 1277.250000 231 0.7890 0
#                   638) B8 <= 2372.435303 8 0.3373 0 *
#                   639) B8 > 2372.435303 85 0.9208 0
#                     1278) B4 <= 1508.849976 77 0.9536 0
#                       2556) B4 <= 1501.750000 34 0.9988 0
#                         5112) B8 <= 2465.416626 8 0.9457 1 *
#                         5113) B8 > 2465.416626 26 0.9766 0
#                           10226) B8 <= 2564.500000 9 0.7496 0 *
#                           10227) B8 > 2564.500000 9 0.9852 0 *
#                       2557) B4 > 1501.750000 8 0.8454 1 *
#                     1279) B4 > 1508.849976 77 0.9536 0
#                       2558) B4 <= 1589.000000 43 0.8717 0
#                         5116) B2 <= 1309.196411 33 0.7642 0
#                           10232) B3 <= 1279.145813 10 0.5226 0 *
#                           10233) B3 > 1279.145813 7 0.0000 0 *
#                         5117) B2 > 1309.196411 33 0.7642 0
#                           10234) B2 <= 1318.791687 8 0.9957 0 *
#                           10235) B2 > 1318.791687 8 0.8631 0 *
#                       2559) B4 > 1589.000000 10 0.9457 1 *
#     5) B2 > 1362.857117 701 0.8458 0
#       10) B2 <= 1367.428528 8 0.6500 1 *
#       11) B2 > 1367.428528 62 0.9948 1
#         22) B4 <= 1483.375000 12 0.8113 0 *
#         23) B4 > 1483.375000 54 1.0000 0
#           46) B4 <= 1570.333313 42 0.9812 1
#             92) B3 <= 1317.707214 12 0.9887 1 *
#             93) B3 > 1317.707214 32 0.8960 1
#               186) B4 <= 1552.533325 11 0.9495 1 *
#               187) B4 > 1552.533325 9 0.3912 1 *
#           47) B4 > 1570.333313 10 0.7496 0 *
#   3) B4 > 1621.663452 1258 0.9991 0
#     6) B3 <= 1366.638916 557 0.7957 1
#       12) B8 <= 2735.474976 154 0.9840 1
#         24) B8 <= 2693.583374 113 1.0000 0
#           48) B2 <= 1245.055542 100 0.9922 1
#             96) B4 <= 1717.522705 10 0.5436 1 *
#             97) B4 > 1717.522705 8 0.3373 1 *
#           49) B2 > 1245.055542 100 0.9922 1
#             98) B4 <= 1739.187500 82 0.9951 0
#               196) B8 <= 2416.125000 65 0.9355 0
#                 392) B4 <= 1639.350037 9 0.8366 1 *
#                 393) B4 > 1639.350037 8 0.9457 0 *
#               197) B8 > 2416.125000 65 0.9355 0
#                 394) B3 <= 1324.729187 48 0.8291 0
#                   788) B3 <= 1251.500000 9 0.8813 0 *
#                   789) B3 > 1251.500000 35 0.6236 0
#                     1578) B3 <= 1307.557129 10 0.0000 0 *
#                     1579) B3 > 1307.557129 26 0.5127 0
#                       3158) B8 <= 2537.833374 8 0.8813 0 *
#                       3159) B8 > 2537.833374 8 0.4690 0 *
#                 395) B3 > 1324.729187 48 0.8291 0
#                   790) B2 <= 1357.250000 7 0.9457 0 *
#                   791) B2 > 1357.250000 6 0.9183 1 *
#             99) B4 > 1739.187500 82 0.9951 0
#               198) B8 <= 2576.500000 8 0.6194 1 *
#               199) B8 > 2576.500000 9 0.8524 1 *
#         25) B8 > 2693.583374 113 1.0000 0
#           50) B2 <= 1307.474365 6 0.7642 0 *
#           51) B2 > 1307.474365 7 0.0000 0 *
#       13) B8 > 2735.474976 154 0.9840 1
#         26) B3 <= 1273.809570 10 0.9984 0 *
#         27) B3 > 1273.809570 41 0.8004 1
#           54) B2 <= 1244.897705 10 0.0000 1 *
#           55) B2 > 1244.897705 31 0.5631 1
#             110) B8 <= 2915.357178 21 0.7335 1
#               220) B8 <= 2839.857178 9 0.6962 1 *
#               221) B8 > 2839.857178 6 1.0000 0 *
#             111) B8 > 2915.357178 6 0.0000 1 *
#     7) B3 > 1366.638916 557 0.7957 1
#       14) B8 <= 3086.400024 403 0.6462 1
#         28) B2 <= 1439.613647 334 0.7092 1
#           56) B4 <= 1893.212524 190 0.5878 1
#             112) B4 <= 1888.333313 121 0.7370 1
#               224) B8 <= 2872.250000 115 0.7081 1
#                 448) B2 <= 1424.599976 103 0.7513 1
#                   896) B8 <= 2772.928589 79 0.8275 1
#                     1792) B4 <= 1691.397583 62 0.7663 1
#                       3584) B3 <= 1373.090881 6 0.6500 1 *
#                       3585) B3 > 1373.090881 12 0.3095 1 *
#                     1793) B4 > 1691.397583 62 0.7663 1
#                       3586) B3 <= 1412.041687 44 0.8435 1
#                         7172) B4 <= 1760.400024 29 0.7131 1
#                           14344) B3 <= 1379.250000 8 1.0000 0 *
#                           14345) B3 > 1379.250000 7 0.4690 1 *
#                         7173) B4 > 1760.400024 29 0.7131 1
#                           14346) B8 <= 2641.928589 6 0.5033 1 *
#                           14347) B8 > 2641.928589 8 0.3534 1 *
#                       3587) B3 > 1412.041687 44 0.8435 1
#                         7174) B4 <= 1762.000000 7 0.9457 1 *
#                         7175) B4 > 1762.000000 8 0.9957 1 *
#                   897) B8 > 2772.928589 79 0.8275 1
#                     1794) B8 <= 2827.666626 9 1.0000 0 *
#                     1795) B8 > 2827.666626 8 0.7642 1 *
#                 449) B2 > 1424.599976 103 0.7513 1
#                   898) B8 <= 2639.159058 13 0.0000 1 *
#                   899) B8 > 2639.159058 11 0.6500 1 *
#               225) B8 > 2872.250000 12 0.0000 1 *
#             113) B4 > 1888.333313 6 0.9852 0 *
#           57) B4 > 1893.212524 190 0.5878 1
#             114) B2 <= 1373.580261 69 0.1845 1
#               228) B8 <= 2921.031250 24 0.0000 1 *
#               229) B8 > 2921.031250 10 0.6723 1 *
#             115) B2 > 1373.580261 35 0.0000 1 *
#         29) B2 > 1439.613647 334 0.7092 1
#           58) B2 <= 1496.562500 144 0.8304 1
#             116) B2 <= 1489.166687 64 0.9457 1
#               232) B2 <= 1446.625000 54 0.7909 1
#                 464) B3 <= 1505.150024 22 0.9544 1
#                   928) B4 <= 1758.183289 8 0.0000 1 *
#                   929) B4 > 1758.183289 8 0.9911 0 *
#                 465) B3 > 1505.150024 6 0.7642 0 *
#               233) B2 > 1446.625000 54 0.7909 1
#                 466) B4 <= 1726.525024 12 0.7871 1 *
#                 467) B4 > 1726.525024 32 0.5993 1
#                   934) B3 <= 1526.274963 20 0.4587 1
#                     1868) B2 <= 1453.299988 8 0.0000 1 *
#                     1869) B2 > 1453.299988 6 0.5917 1 *
#                   935) B3 > 1526.274963 6 0.7642 1 *
#             117) B2 > 1489.166687 10 0.4855 0 *
#           59) B2 > 1496.562500 144 0.8304 1
#             118) B3 <= 1687.379822 80 0.6808 1
#               236) B3 <= 1648.884644 69 0.7444 1
#                 472) B8 <= 2528.449951 6 0.9911 0 *
#                 473) B8 > 2528.449951 63 0.6862 1
#                   946) B4 <= 2024.549988 57 0.5917 1
#                     1892) B4 <= 2010.559570 50 0.6447 1
#                       3784) B3 <= 1505.312500 44 0.5381 1
#                         7568) B2 <= 1509.236267 7 0.5917 1 *
#                         7569) B2 > 1509.236267 7 0.8454 1 *
#                       3785) B3 > 1505.312500 44 0.5381 1
#                         7570) B2 <= 1550.325012 18 0.0000 1 *
#                         7571) B2 > 1550.325012 12 0.7425 1 *
#                     1893) B4 > 2010.559570 6 1.0000 0 *
#                   947) B4 > 2024.549988 7 0.0000 1 *
#               237) B3 > 1648.884644 6 0.9940 1 *
#             119) B3 > 1687.379822 11 0.0000 1 *
#       15) B8 > 3086.400024 403 0.6462 1
#         30) B3 <= 1891.176880 63 0.0000 1 *
#         31) B3 > 1891.176880 6 0.7642 1 *

# %%
# number of trees we converted should equal the number of trees we defined for the model
len(trees) == n_trees
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# False

# %% [markdown]
# ## Convert sklearn classifier to GEE classifier
#
# At this point you can take the list of strings and save them locally to avoid training again. However, we want to use the model with EE so we need to create an ee.Classifier and persist the data on ee for best results.

# %%
# create a ee classifier to use with ee objects from the trees
ee_classifier = ml.strings_to_classifier(trees)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee_classifier.getInfo()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Classify image using GEE classifier

# %%
# get Sentinel-2 imagery and create median composite
# mask clouds?
start_date = ee.Date('2020-01-01')
end_date = start_date.advance(365, 'day')
bands = ['B2', 'B3', 'B4', 'B8']
image = ee.ImageCollection('COPERNICUS/S2').filterDate(start_date, end_date).select(bands).median()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# classify the image using the classifier we created from the local training
# note: here we select the feature_names from the image that way the classifier knows which bands to use
classified = image.select(feature_names).classify(ee_classifier)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# display results
Map = geemap.Map(center=(-18.67769, 26.27313), zoom=8)

Map.addLayer(
    image,
    {"bands": ['B2', 'B3', 'B4'], "min": 0, "max": 3000},
    'image',
)
Map.addLayer(
    classified,
    {"min": 0, "max": 1, "palette": ['beige', 'green']},
    'classification',
)

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-18.67769, 26.27313], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=Searc…

# %% [markdown]
# Yay!! 🎉 Looks like our example works. Don't party too much because there is a catch...
#
# This workflow has several limitations particularly due to how much data you can pass from the client to the server and how large of a model ee can actually handle. EE can only handle 40MB of data passed to the server, so if you have a lot of large decision tree strings then this will not work. Also, creating a classifier from strings has limitation (see this ee-forum discussion: https://groups.google.com/g/google-earth-engine-developers/c/lFFU1GBPzi8/m/6MewQk1FBwAJ), this is again limited by string lengths when ee creates a computation graph.
#
# So, you can use this but know you will probably run into errors when training large models.

# %% [markdown]
# ## Save trees to the cloud
#
# Now we have the strings in a format that ee can use, we want to save it for later use. There is a function to export a list of tree strings to a feature collection. The feature collection will have a pro

# %%
user_id = geemap.ee_user_id()
user_id
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 'users/alexvmt'

# %%
# specify asset id where to save trees
# be sure to change <user_name> to your ee user name
asset_id = user_id + "/random_forest_strings_test"
asset_id
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 'users/alexvmt/random_forest_strings_test'

# %%
# kick off an export process so it will be saved to the ee asset
ml.export_trees_to_fc(trees, asset_id)

# this will kick off an export task, so wait a few minutes before moving on
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# read the exported tree feature collection
rf_fc = ee.FeatureCollection(asset_id)

# convert it to a classifier, very similar to the `ml.trees_to_classifier` function
another_classifier = ml.fc_to_classifier(rf_fc)

# classify the image again but with the classifier from the persisted trees
classified = image.select(feature_names).classify(another_classifier)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# display results
# we should get the exact same results as before
Map = geemap.Map(center=(-18.67769, 26.27313), zoom=8)

Map.addLayer(
    image,
    {"bands": ['B2', 'B3', 'B4'], "min": 0, "max": 3000},
    'image',
)
Map.addLayer(
    classified,
    {"min": 0, "max": 1, "palette": ['beige', 'green']},
    'classification',
)

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-18.67769, 26.27313], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=Searc…

# %% [markdown]
# ## Save trees locally

# %%
import os

out_csv = os.path.expanduser("trees.csv")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ml.trees_to_csv(trees, out_csv)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
another_classifier = ml.csv_to_classifier(out_csv)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
classified = image.select(feature_names).classify(another_classifier)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# display results
# we should get the exact same results as before
Map = geemap.Map(center=(-18.67769, 26.27313), zoom=8)

Map.addLayer(
    image,
    {"bands": ['B2', 'B3', 'B4'], "min": 0, "max": 3000},
    'image',
)
Map.addLayer(
    classified,
    {"min": 0, "max": 1, "palette": ['beige', 'green']},
    'classification',
)

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-18.67769, 26.27313], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=Searc…
