# %% [markdown]
# # Train and test set
#
# ### Feature groups
# - raw Sentinel-2 bands
# - indices based on raw Sentinel-2 bands (e.g. NDVI, NDWI, SAVI, EVI)
#
# ### More advanced ideas
# - seasonal quarterly and monthly time series
# - min, max, median indices

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/land_cover_classification_kaza
# Out:
# /content/drive/MyDrive/land_cover_classification_kaza

# %% [markdown]
# ## Load and prepare raw data
#
# We're using the labels provided by Nuno and the according Sentinel-2 bands.

# %%
raw_data = pd.read_csv('data/raw_data.csv')
raw_data.shape
# Out:
# (267442, 15)

# %%
raw_data
# Out:
#                     system:index     B11     B12     B2      B3      B4  \
# 0         00000000000000000010_0  2970.5  2088.5  763.0  1005.5  1389.0
# 1         00000000000000000010_1  3070.0  2153.0  764.0   992.0  1448.0
# 2         00000000000000000010_2  3070.0  2153.0  746.0   978.0  1385.0
# 3         00000000000000000010_3  3024.5  2069.0  724.0   923.0  1372.0
# 4         00000000000000000010_4  3024.5  2069.0  714.5   913.0  1347.0
# ...                          ...     ...     ...    ...     ...     ...
# 267437  00000000000000000561_158  2304.5  1836.5  500.0   605.5   722.5
# 267438  00000000000000000561_159  2197.5  1720.5  497.5   618.0   734.0
# 267439  00000000000000000561_160  2197.5  1720.5  515.0   622.5   759.0
# 267440  00000000000000000561_161  2304.5  1836.5  504.5   571.0   689.0
# 267441  00000000000000000561_162  2197.5  1720.5  480.0   583.0   686.0
#
#             B5      B6      B7      B8     B8A  LC_Nr      LC_Out Landcover  \
# 0       1640.0  2035.5  2232.0  2549.0  2571.0      4  Active cro  Cropland
# 1       1702.5  2092.5  2293.5  2560.0  2608.0      4  Active cro  Cropland
# 2       1702.5  2092.5  2293.5  2542.0  2608.0      4  Active cro  Cropland
# 3       1659.5  2010.0  2228.0  2447.5  2552.5      4  Active cro  Cropland
# 4       1659.5  2010.0  2228.0  2427.5  2552.5      4  Active cro  Cropland
# ...        ...     ...     ...     ...     ...    ...         ...       ...
# 267437  1036.0  1484.5  1662.5  1650.0  1935.5      8     Wetland   Wetland
# 267438  1005.0  1422.5  1600.0  1651.0  1843.0      8     Wetland   Wetland
# 267439  1005.0  1422.5  1600.0  1642.0  1843.0      8     Wetland   Wetland
# 267440  1036.0  1484.5  1662.5  1702.0  1935.5      8     Wetland   Wetland
# 267441  1005.0  1422.5  1600.0  1717.0  1843.0      8     Wetland   Wetland
#
#                                                      .geo
# 0       {"geodesic":false,"type":"Point","coordinates"...
# 1       {"geodesic":false,"type":"Point","coordinates"...
# 2       {"geodesic":false,"type":"Point","coordinates"...
# 3       {"geodesic":false,"type":"Point","coordinates"...
# 4       {"geodesic":false,"type":"Point","coordinates"...
# ...                                                   ...
# 267437  {"geodesic":false,"type":"Point","coordinates"...
# 267438  {"geodesic":false,"type":"Point","coordinates"...
# 267439  {"geodesic":false,"type":"Point","coordinates"...
# 267440  {"geodesic":false,"type":"Point","coordinates"...
# 267441  {"geodesic":false,"type":"Point","coordinates"...
#
# [267442 rows x 15 columns]

# %%
raw_data = raw_data.drop(['system:index', '.geo'], axis=1)

# %%
# remove land cover class deforestation as it is not needed in this use case
raw_data = raw_data[raw_data['Landcover'] != 'Deforestation']
raw_data.shape
# Out:
# (261066, 13)

# %%
raw_data['Landcover'] = raw_data['Landcover'].str.capitalize()

# %% [markdown]
# ## Downsample and balance raw data

# %%
raw_data['Landcover'].value_counts()
# Out:
# Forest      117277
# Cropland     58759
# Wetland      45501
# Shrub        27552
# Grass        10826
# Bare           475
# Water          376
# Built up       300
# Name: Landcover, dtype: int64

# %%
raw_data['LC_Nr'].value_counts()
# Out:
# 7    117277
# 4     58759
# 8     45501
# 6     27552
# 5     10826
# 2       475
# 1       376
# 3       300
# Name: LC_Nr, dtype: int64

# %%
def sample_train_and_test_data(df, land_cover_class, train_fraction, desired_train_samples=None):

  random_state = 42

  # filter and shuffle df
  df = df[df['Landcover'] == land_cover_class]
  df = df.sample(frac=1, random_state=random_state).reset_index(drop=True)

  # calculate n train samples
  n_train_samples = int(round(df.shape[0] * train_fraction, 0))

  # sample train and test samples
  train_samples = df.iloc[:n_train_samples]
  test_samples = df.iloc[n_train_samples:]

  # downsample train samples if specified
  if desired_train_samples is not None:
    train_samples = train_samples.sample(n=desired_train_samples, random_state=random_state).reset_index(drop=True)

  print(f'land cover class: {land_cover_class}; train samples: {train_samples.shape[0]}; test samples: {test_samples.shape[0]}')

  return train_samples, test_samples

# %%
train_fraction = 0.7
train_forest, test_forest = sample_train_and_test_data(raw_data, 'Forest', train_fraction, desired_train_samples=500)
train_cropland, test_cropland = sample_train_and_test_data(raw_data, 'Cropland', train_fraction, desired_train_samples=500)
train_wetland, test_wetland = sample_train_and_test_data(raw_data, 'Wetland', train_fraction, desired_train_samples=500)
train_shrub, test_shrub = sample_train_and_test_data(raw_data, 'Shrub', train_fraction, desired_train_samples=500)
train_grass, test_grass = sample_train_and_test_data(raw_data, 'Grass', train_fraction, desired_train_samples=500)
train_bare, test_bare = sample_train_and_test_data(raw_data, 'Bare', train_fraction)
train_water, test_water = sample_train_and_test_data(raw_data, 'Water', train_fraction)
train_built_up, test_built_up = sample_train_and_test_data(raw_data, 'Built up', train_fraction)
# Out:
# land cover class: Forest; train samples: 500; test samples: 35183
# land cover class: Cropland; train samples: 500; test samples: 17628
# land cover class: Wetland; train samples: 500; test samples: 13650
# land cover class: Shrub; train samples: 500; test samples: 8266
# land cover class: Grass; train samples: 500; test samples: 3248
# land cover class: Bare; train samples: 332; test samples: 143
# land cover class: Water; train samples: 263; test samples: 113
# land cover class: Built up; train samples: 210; test samples: 90

# %%
train = pd.concat([train_forest, train_cropland, train_wetland, train_shrub, train_grass, train_bare, train_water, train_built_up], ignore_index=True)
train
# Out:
#               B11          B12           B2           B3           B4  \
# 0     2006.000000  1215.000000   522.100000   701.937500   810.666667
# 1     1903.000000  1237.500000   404.000000   529.000000   551.000000
# 2     2244.500000  1337.666667   476.500000   696.375000   735.000000
# 3     2029.000000  1238.000000   450.000000   622.000000   693.000000
# 4     2249.000000  1340.750000   498.000000   707.000000   797.500000
# ...           ...          ...          ...          ...          ...
# 3300  3092.666667  2532.000000   866.500000  1101.500000  1475.000000
# 3301  3588.000000  3187.500000  1151.000000  1325.000000  2030.700000
# 3302  3474.400000  2907.500000  1121.000000  1458.833333  1844.000000
# 3303  3429.250000  3303.000000  1203.333333  1398.000000  1782.000000
# 3304  3502.583333  2949.750000  1238.000000  1582.000000  1866.666667
#
#                B5           B6           B7           B8          B8A  LC_Nr  \
# 0     1098.000000  1695.750000  1901.000000  2257.333333  2226.000000      7
# 1      952.666667  1618.800000  1868.500000  1861.500000  2135.000000      7
# 2     1156.250000  1856.625000  2145.750000  2619.000000  2523.500000      7
# 3     1056.000000  1666.000000  1925.000000  2076.000000  2252.000000      7
# 4     1241.500000  1904.416667  2156.500000  2371.600000  2507.500000      7
# ...           ...          ...          ...          ...          ...    ...
# 3300  1689.750000  1899.000000  2054.833333  2287.000000  2368.250000      3
# 3301  2052.250000  2444.166667  2571.083333  2662.666667  2812.333333      3
# 3302  2013.000000  2354.500000  2526.928571  2717.166667  2771.857143      3
# 3303  1736.000000  1926.000000  2068.000000  2502.000000  2315.000000      3
# 3304  2007.625000  2339.800000  2570.750000  2526.333333  2776.416667      3
#
#         LC_Out Landcover
# 0       Forest    Forest
# 1       Forest    Forest
# 2       Forest    Forest
# 3       Forest    Forest
# 4       Forest    Forest
# ...        ...       ...
# 3300  Built-up  Built up
# 3301  Built-up  Built up
# 3302  Built-up  Built up
# 3303  Built-up  Built up
# 3304  Built-up  Built up
#
# [3305 rows x 13 columns]

# %%
test = pd.concat([test_forest, test_cropland, test_wetland, test_shrub, test_grass, test_bare, test_water, test_built_up], ignore_index=True)
test
# Out:
#                B11          B12           B2           B3           B4  \
# 0      1492.200000   754.666667   326.363636   454.545455   359.500000
# 1      1393.000000   654.000000   286.000000   404.000000   324.000000
# 2      1879.500000  1112.333333   387.750000   539.750000   563.666667
# 3      1854.666667  1055.000000   358.000000   486.600000   515.000000
# 4      2185.600000  1432.500000   491.800000   686.384615   810.200000
# ...            ...          ...          ...          ...          ...
# 78316  2933.750000  2918.666667   972.400000  1253.000000  1621.333333
# 78317  3748.500000  3796.857143  1192.666667  1412.000000  1753.000000
# 78318  3832.000000  3842.883333  1321.200000  1558.500000  1933.800000
# 78319  3834.500000  3540.500000  1269.000000  1395.000000  1776.000000
# 78320  3876.666667  3905.250000  1221.333333  1444.500000  1810.000000
#
#                 B5        B6           B7           B8          B8A  LC_Nr  \
# 0       741.000000  1498.500  1754.666667  1896.500000  1956.000000      7
# 1       656.000000  1472.000  1695.000000  1758.000000  1890.000000      7
# 2       967.500000  1588.750  1797.000000  1792.000000  2065.250000      7
# 3       882.333333  1581.000  1811.250000  1846.000000  2100.250000      7
# 4      1173.285714  1643.125  1868.714286  2091.500000  2164.222222      7
# ...            ...       ...          ...          ...          ...    ...
# 78316  1959.000000  2026.000  2106.166667  1894.000000  2159.750000      3
# 78317  2074.333333  2197.000  2339.500000  2432.000000  2625.000000      3
# 78318  2081.000000  2198.000  2375.333333  2643.000000  2629.500000      3
# 78319  1950.500000  2181.000  2431.500000  2635.000000  2786.500000      3
# 78320  2071.250000  2229.125  2389.000000  2477.333333  2659.500000      3
#
#          LC_Out Landcover
# 0        Forest    Forest
# 1        Forest    Forest
# 2        Forest    Forest
# 3        Forest    Forest
# 4        Forest    Forest
# ...         ...       ...
# 78316  Built-up  Built up
# 78317  Built-up  Built up
# 78318  Built-up  Built up
# 78319  Built-up  Built up
# 78320  Built-up  Built up
#
# [78321 rows x 13 columns]

# %% [markdown]
# ## Compute indices

# %%
# !pip install spyndex
# Out:
# Collecting spyndex
#   Downloading spyndex-0.5.0.tar.gz (727 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.5/727.5 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dask>=2023.7.0 in /usr/local/lib/python3.10/dist-packages (from spyndex) (2023.8.1)
# Collecting eemont>=0.3.6 (from spyndex)
#   Downloading eemont-0.3.6.tar.gz (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.7/134.7 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from spyndex) (3.7.1)
# Collecting pandas>=2.0.3 (from spyndex)
#   Downloading pandas-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 46.3 MB/s eta 0:00:00
# Requirement already satisfied: python-box>=6.0 in /usr/local/lib/python3.10/dist-packages (from spyndex) (7.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from spyndex) (2.31.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from spyndex) (0.13.1)
# Requirement already satisfied: xarray>=2023.6.0 in /usr/local/lib/python3.10/dist-packages (from spyndex) (2023.7.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->spyndex) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->spyndex) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->spyndex) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->spyndex) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->spyndex) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->spyndex) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->spyndex) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->spyndex) (7.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from eemont>=0.3.6->spyndex) (4.12.3)
# Requirement already satisfied: earthengine-api in /usr/local/lib/python3.10/dist-packages (from eemont>=0.3.6->spyndex) (0.1.393)
# Collecting ee_extra>=0.0.15 (from eemont>=0.3.6->spyndex)
#   Downloading ee_extra-0.0.15.tar.gz (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 kB 20.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from eemont>=0.3.6->spyndex) (1.25.2)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from eemont>=0.3.6->spyndex) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->spyndex) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->spyndex) (2023.4)
# Collecting tzdata>=2022.7 (from pandas>=2.0.3->spyndex)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spyndex) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spyndex) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spyndex) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spyndex) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spyndex) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->spyndex) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->spyndex) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->spyndex) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->spyndex) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->spyndex) (2024.2.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2023.7.0->spyndex) (3.17.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask>=2023.7.0->spyndex) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.3->spyndex) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->eemont>=0.3.6->spyndex) (2.5)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (from earthengine-api->eemont>=0.3.6->spyndex) (2.8.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from earthengine-api->eemont>=0.3.6->spyndex) (2.84.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from earthengine-api->eemont>=0.3.6->spyndex) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from earthengine-api->eemont>=0.3.6->spyndex) (0.1.1)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from earthengine-api->eemont>=0.3.6->spyndex) (0.22.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->eemont>=0.3.6->spyndex) (2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.12.1->earthengine-api->eemont>=0.3.6->spyndex) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.12.1->earthengine-api->eemont>=0.3.6->spyndex) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api->eemont>=0.3.6->spyndex) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api->eemont>=0.3.6->spyndex) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api->eemont>=0.3.6->spyndex) (4.9)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->earthengine-api->eemont>=0.3.6->spyndex) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->earthengine-api->eemont>=0.3.6->spyndex) (2.7.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->eemont>=0.3.6->spyndex) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->eemont>=0.3.6->spyndex) (3.20.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api->eemont>=0.3.6->spyndex) (1.5.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api->eemont>=0.3.6->spyndex) (0.5.1)
# Building wheels for collected packages: spyndex, eemont, ee_extra
#   Building wheel for spyndex (setup.py) ... done
#   Created wheel for spyndex: filename=spyndex-0.5.0-py3-none-any.whl size=767326 sha256=974c5f53dc89250ebf0350ceb3d2d775e479b92261c66511b8f6a60a1a50e331
#   Stored in directory: /root/.cache/pip/wheels/f7/1e/f4/b5ed10a287c3131930e96208638cfb906f3337da44a3fdf447
#   Building wheel for eemont (setup.py) ... done
#   Created wheel for eemont: filename=eemont-0.3.6-py3-none-any.whl size=135742 sha256=da21067ee8c78d26bc884f877e1261b4989c30bb0e61f9a0617f1ae13d9b44fa
#   Stored in directory: /root/.cache/pip/wheels/c2/79/2c/4fed17c3d3b466bbf4fe5872eec11f189147043b01152a4f75
#   Building wheel for ee_extra (setup.py) ... done
#   Created wheel for ee_extra: filename=ee_extra-0.0.15-py3-none-any.whl size=236756 sha256=2fc411f48bc23ab763220a8660406da7b9afd968dbee03043ce3c997cf42e854
#   Stored in directory: /root/.cache/pip/wheels/29/96/0e/4e36b0dfd85e16867723df739294c0aa45a65b191adac4d959
# Successfully built spyndex eemont ee_extra
# Installing collected packages: tzdata, pandas, ee_extra, eemont, spyndex
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.23.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.1 which is incompatible.
# Successfully installed ee_extra-0.0.15 eemont-0.3.6 pandas-2.2.1 spyndex-0.5.0 tzdata-2024.1

# %%
import spyndex

# %%
idx = spyndex.computeIndex(
    index = ['NDVI', 'NDWI', 'SAVI', 'EVI'],
    params = {
        'R': train['B4'],
        'G': train['B3'],
        'B': train['B2'],
        'N': train['B8'],
        'S1': train['B11'],
        'S2': train['B12'],
        'g': 2.5,
        'L': 0.5,
        'C1': 6,
        'C2': 7.5

    }
)
train = pd.concat([train, idx], axis=1)
train
# Out:
#               B11          B12           B2           B3           B4  \
# 0     2006.000000  1215.000000   522.100000   701.937500   810.666667
# 1     1903.000000  1237.500000   404.000000   529.000000   551.000000
# 2     2244.500000  1337.666667   476.500000   696.375000   735.000000
# 3     2029.000000  1238.000000   450.000000   622.000000   693.000000
# 4     2249.000000  1340.750000   498.000000   707.000000   797.500000
# ...           ...          ...          ...          ...          ...
# 3300  3092.666667  2532.000000   866.500000  1101.500000  1475.000000
# 3301  3588.000000  3187.500000  1151.000000  1325.000000  2030.700000
# 3302  3474.400000  2907.500000  1121.000000  1458.833333  1844.000000
# 3303  3429.250000  3303.000000  1203.333333  1398.000000  1782.000000
# 3304  3502.583333  2949.750000  1238.000000  1582.000000  1866.666667
#
#                B5           B6           B7           B8          B8A  LC_Nr  \
# 0     1098.000000  1695.750000  1901.000000  2257.333333  2226.000000      7
# 1      952.666667  1618.800000  1868.500000  1861.500000  2135.000000      7
# 2     1156.250000  1856.625000  2145.750000  2619.000000  2523.500000      7
# 3     1056.000000  1666.000000  1925.000000  2076.000000  2252.000000      7
# 4     1241.500000  1904.416667  2156.500000  2371.600000  2507.500000      7
# ...           ...          ...          ...          ...          ...    ...
# 3300  1689.750000  1899.000000  2054.833333  2287.000000  2368.250000      3
# 3301  2052.250000  2444.166667  2571.083333  2662.666667  2812.333333      3
# 3302  2013.000000  2354.500000  2526.928571  2717.166667  2771.857143      3
# 3303  1736.000000  1926.000000  2068.000000  2502.000000  2315.000000      3
# 3304  2007.625000  2339.800000  2570.750000  2526.333333  2776.416667      3
#
#         LC_Out Landcover      NDVI      NDWI      SAVI       EVI
# 0       Forest    Forest  0.471534 -0.525601  0.707186  1.128064
# 1       Forest    Forest  0.543212 -0.557415  0.814650  1.532390
# 2       Forest    Forest  0.561717 -0.579912  0.842450  1.362946
# 3       Forest    Forest  0.499458 -0.538918  0.749052  1.209127
# 4       Forest    Forest  0.496703 -0.540700  0.744936  1.149952
# ...        ...       ...       ...       ...       ...       ...
# 3300  Built-up  Built up  0.215843 -0.349860  0.323721  0.437618
# 3301  Built-up  Built up  0.134651 -0.335451  0.201955  0.254216
# 3302  Built-up  Built up  0.191435 -0.301325  0.287121  0.406187
# 3303  Built-up  Built up  0.168067 -0.283077  0.252071  0.431706
# 3304  Built-up  Built up  0.150163 -0.229858  0.225219  0.371281
#
# [3305 rows x 17 columns]

# %%
idx = spyndex.computeIndex(
    index = ['NDVI', 'NDWI', 'SAVI', 'EVI'],
    params = {
        'R': test['B4'],
        'G': test['B3'],
        'B': test['B2'],
        'N': test['B8'],
        'S1': test['B11'],
        'S2': test['B12'],
        'g': 2.5,
        'L': 0.5,
        'C1': 6,
        'C2': 7.5

    }
)
test = pd.concat([test, idx], axis=1)
test
# Out:
#                B11          B12           B2           B3           B4  \
# 0      1492.200000   754.666667   326.363636   454.545455   359.500000
# 1      1393.000000   654.000000   286.000000   404.000000   324.000000
# 2      1879.500000  1112.333333   387.750000   539.750000   563.666667
# 3      1854.666667  1055.000000   358.000000   486.600000   515.000000
# 4      2185.600000  1432.500000   491.800000   686.384615   810.200000
# ...            ...          ...          ...          ...          ...
# 78316  2933.750000  2918.666667   972.400000  1253.000000  1621.333333
# 78317  3748.500000  3796.857143  1192.666667  1412.000000  1753.000000
# 78318  3832.000000  3842.883333  1321.200000  1558.500000  1933.800000
# 78319  3834.500000  3540.500000  1269.000000  1395.000000  1776.000000
# 78320  3876.666667  3905.250000  1221.333333  1444.500000  1810.000000
#
#                 B5        B6           B7           B8          B8A  LC_Nr  \
# 0       741.000000  1498.500  1754.666667  1896.500000  1956.000000      7
# 1       656.000000  1472.000  1695.000000  1758.000000  1890.000000      7
# 2       967.500000  1588.750  1797.000000  1792.000000  2065.250000      7
# 3       882.333333  1581.000  1811.250000  1846.000000  2100.250000      7
# 4      1173.285714  1643.125  1868.714286  2091.500000  2164.222222      7
# ...            ...       ...          ...          ...          ...    ...
# 78316  1959.000000  2026.000  2106.166667  1894.000000  2159.750000      3
# 78317  2074.333333  2197.000  2339.500000  2432.000000  2625.000000      3
# 78318  2081.000000  2198.000  2375.333333  2643.000000  2629.500000      3
# 78319  1950.500000  2181.000  2431.500000  2635.000000  2786.500000      3
# 78320  2071.250000  2229.125  2389.000000  2477.333333  2659.500000      3
#
#          LC_Out Landcover      NDVI      NDWI      SAVI       EVI
# 0        Forest    Forest  0.681294 -0.613325  1.021715  2.392184
# 1        Forest    Forest  0.688761 -0.626272  1.032893  2.301766
# 2        Forest    Forest  0.521438 -0.537043  0.781991  1.354954
# 3        Forest    Forest  0.563744 -0.582783  0.845437  1.477904
# 4        Forest    Forest  0.441569 -0.505822  0.662239  0.981177
# ...         ...       ...       ...       ...       ...       ...
# 78316  Built-up  Built up  0.077565 -0.203686  0.116331  0.157447
# 78317  Built-up  Built up  0.162246 -0.265349  0.243340  0.423792
# 78318  Built-up  Built up  0.154955 -0.258122  0.232408  0.408780
# 78319  Built-up  Built up  0.194740 -0.307692  0.292078  0.569025
# 78320  Built-up  Built up  0.155652 -0.263355  0.233451  0.399330
#
# [78321 rows x 17 columns]

# %% [markdown]
# ## Save train and test set

# %%
train.to_csv('data/train.csv', index=False)
test.to_csv('data/test.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-eb3a29987bb6> in <cell line: 1>()
# ----> 1 train.to_csv('data/train.csv', index=False)
#       2 test.to_csv('data/test.csv', index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                         f"or {repr(new_arg_name)}, not both."
#     210                     )
# --> 211                     raise TypeError(msg)
#     212                 kwargs[new_arg_name] = new_arg_value
#     213             return func(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718             If buf is None, returns the result as a string. Otherwise returns None.
#    3719         """
# -> 3720         from pandas.io.formats.style import Styler
#    3721
#    3722         self = cast("DataFrame", self)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                         f"or {repr(new_arg_name)}, not both."
#     210                     )
# --> 211                     raise TypeError(msg)
#     212                 kwargs[new_arg_name] = new_arg_value
#     213             return func(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1160
#    1161     return fmt_obj.get_result()
# -> 1162
#    1163
#    1164 class _GenericArrayFormatter:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in <module>
#      22
#      23 from pandas._libs import writers as libwriters
# ---> 24 from pandas._typing import SequenceNotStr
#      25 from pandas.util._decorators import cache_readonly
#      26
#
# ImportError: cannot import name 'SequenceNotStr' from 'pandas._typing' (/usr/local/lib/python3.10/dist-packages/pandas/_typing.py)
