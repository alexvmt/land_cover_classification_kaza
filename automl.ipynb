# %% [markdown]
# # AutoML
#
# ### Resources
# - https://github.com/automl/auto-sklearn/issues/1684
# - https://geemap.org/notebooks/46_local_rf_training/

# %% [markdown]
# ## Install auto-sklearn

# %%
# 1. uninstall all affected packages
# !pip uninstall -y Cython scipy pyparsing scikit_learn imbalanced-learn mlxtend yellowbrick
# Out:
# Found existing installation: Cython 3.0.9
# Uninstalling Cython-3.0.9:
#   Successfully uninstalled Cython-3.0.9
# Found existing installation: scipy 1.11.4
# Uninstalling scipy-1.11.4:
#   Successfully uninstalled scipy-1.11.4
# Found existing installation: pyparsing 3.1.1
# Uninstalling pyparsing-3.1.1:
#   Successfully uninstalled pyparsing-3.1.1
# Found existing installation: scikit-learn 1.2.2
# Uninstalling scikit-learn-1.2.2:
#   Successfully uninstalled scikit-learn-1.2.2
# Found existing installation: imbalanced-learn 0.10.1
# Uninstalling imbalanced-learn-0.10.1:
#   Successfully uninstalled imbalanced-learn-0.10.1
# Found existing installation: mlxtend 0.22.0
# Uninstalling mlxtend-0.22.0:
#   Successfully uninstalled mlxtend-0.22.0
# Found existing installation: yellowbrick 1.5
# Uninstalling yellowbrick-1.5:
#   Successfully uninstalled yellowbrick-1.5

# %%
# 2. install packages to be downgraded
# !pip install Cython==0.29.36 scipy==1.9 pyparsing==2.4
# Out:
# Collecting Cython==0.29.36
#   Downloading Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 7.2 MB/s eta 0:00:00
# Collecting scipy==1.9
#   Downloading scipy-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 11.8 MB/s eta 0:00:00
# Collecting pyparsing==2.4
#   Downloading pyparsing-2.4.0-py2.py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.6 MB/s eta 0:00:00
# Collecting numpy<1.25.0,>=1.18.5 (from scipy==1.9)
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 24.1 MB/s eta 0:00:00
# Installing collected packages: pyparsing, numpy, Cython, scipy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.14 requires scikit-learn, which is not installed.
# librosa 0.10.1 requires scikit-learn>=0.20.0, which is not installed.
# qudida 0.0.4 requires scikit-learn>=0.19.1, which is not installed.
# sklearn-pandas 2.2.0 requires scikit-learn>=0.23.0, which is not installed.
# httplib2 0.22.0 requires pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2; python_version > "3.0", but you have pyparsing 2.4.0 which is incompatible.
# Successfully installed Cython-0.29.36 numpy-1.24.4 pyparsing-2.4.0 scipy-1.9.0

# %%
# 3. install older scikit-learn disregarding its dependencies
# !pip install scikit-learn==0.24.2 --no-build-isolation
# Out:
# Collecting scikit-learn==0.24.2
#   Downloading scikit-learn-0.24.2.tar.gz (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 11.7 MB/s eta 0:00:00
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (1.24.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (1.9.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (3.3.0)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (pyproject.toml) ... done
#   Created wheel for scikit-learn: filename=scikit_learn-0.24.2-cp310-cp310-linux_x86_64.whl size=22238008 sha256=0bc5e4ed3fec93d79b308ec2211bb87653e2e0a16f832f04b206a086c815ac04
#   Stored in directory: /root/.cache/pip/wheels/13/a4/68/4e78865652fa14db4a162b491e5138565f97646f9e1f2ab8cc
# Successfully built scikit-learn
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.22.0 requires scikit-learn>=1.2.2, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed scikit-learn-0.24.2

# %%
# 4. finally install auto-sklearn
# !pip install auto-sklearn
# Out:
# Collecting auto-sklearn
#   Downloading auto-sklearn-0.15.0.tar.gz (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 18.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (4.10.0)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from auto-sklearn) (1.7.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (1.24.4)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (1.9.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (1.3.2)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (0.24.2)
# Requirement already satisfied: dask>=2021.12 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (2023.8.1)
# Requirement already satisfied: distributed>=2012.12 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (2023.8.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (6.0.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (1.5.3)
# Collecting liac-arff (from auto-sklearn)
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from auto-sklearn) (3.3.0)
# Collecting ConfigSpace<0.5,>=0.4.21 (from auto-sklearn)
#   Downloading ConfigSpace-0.4.21-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 28.0 MB/s eta 0:00:00
# Collecting pynisher<0.7,>=0.6.3 (from auto-sklearn)
#   Downloading pynisher-0.6.4.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyrfr<0.9,>=0.8.1 (from auto-sklearn)
#   Downloading pyrfr-0.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 22.8 MB/s eta 0:00:00
# Collecting smac<1.3,>=1.2 (from auto-sklearn)
#   Downloading smac-1.2.tar.gz (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (0.29.36)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (2.4.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.12->auto-sklearn) (7.0.1)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (3.1.3)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (1.0.8)
# Requirement already satisfied: psutil>=5.7.2 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (6.3.3)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (2.0.7)
# Requirement already satisfied: zict>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2012.12->auto-sklearn) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->auto-sklearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->auto-sklearn) (2023.4)
# Collecting emcee>=3.0.0 (from smac<1.3,>=1.2->auto-sklearn)
#   Downloading emcee-3.1.4-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2021.12->auto-sklearn) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed>=2012.12->auto-sklearn) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->auto-sklearn) (1.16.0)
# Building wheels for collected packages: auto-sklearn, pynisher, smac, liac-arff
#   Building wheel for auto-sklearn (pyproject.toml) ... done
#   Created wheel for auto-sklearn: filename=auto_sklearn-0.15.0-py3-none-any.whl size=6641936 sha256=efc2d7103a4866ed98301953a5b79a4595f4176948296dfda7e9a3c3bbfdad71
#   Stored in directory: /root/.cache/pip/wheels/4d/0a/f9/8c1a06bcc36bc16b467b044b5bb03a90f92a5c5e6cd443414b
#   Building wheel for pynisher (setup.py) ... done
#   Created wheel for pynisher: filename=pynisher-0.6.4-py3-none-any.whl size=7026 sha256=353db5e2801b97df9e8bd0cc780440f5f3838d443efdc83aca37c05da9419422
#   Stored in directory: /root/.cache/pip/wheels/90/7b/53/b21d6b41910f43c7f1557262e579598f83e75e44c659c1bcce
#   Building wheel for smac (setup.py) ... done
#   Created wheel for smac: filename=smac-1.2-py3-none-any.whl size=215906 sha256=a510e43491b337cf7b848c0e497169be07fe73c5b3057e05ab668aea5a6e4db6
#   Stored in directory: /root/.cache/pip/wheels/66/2e/d9/2db14bdfcdc36bf12e202b44201df03f194367fcfd85ce2778
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11716 sha256=275a1fe71b95192da052c6cf322874a1dec1684d9032cc5aa37bba66f7f9be0c
#   Stored in directory: /root/.cache/pip/wheels/5d/2a/9c/3895d9617f8f49a0883ba686326d598e78a1c2f54fe3cae86d
# Successfully built auto-sklearn pynisher smac liac-arff
# Installing collected packages: pyrfr, pynisher, liac-arff, emcee, ConfigSpace, smac, auto-sklearn
# Successfully installed ConfigSpace-0.4.21 auto-sklearn-0.15.0 emcee-3.1.4 liac-arff-2.5.0 pynisher-0.6.4 pyrfr-0.8.3 smac-1.2

# %%
# 5. then, try loading the package repeatedly until trash in its dependencies are clean
#import autosklearn

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
import pandas as pd
import autosklearn.classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/land_cover_classification_kaza
# Out:
# /content/drive/MyDrive/land_cover_classification_kaza

# %% [markdown]
# ## Load train and test set

# %%
train = pd.read_csv('data/train.csv')
train
# Out:
#               B11          B12           B2           B3           B4  \
# 0     2006.000000  1215.000000   522.100000   701.937500   810.666667
# 1     1903.000000  1237.500000   404.000000   529.000000   551.000000
# 2     2244.500000  1337.666667   476.500000   696.375000   735.000000
# 3     2029.000000  1238.000000   450.000000   622.000000   693.000000
# 4     2249.000000  1340.750000   498.000000   707.000000   797.500000
# ...           ...          ...          ...          ...          ...
# 3300  3092.666667  2532.000000   866.500000  1101.500000  1475.000000
# 3301  3588.000000  3187.500000  1151.000000  1325.000000  2030.700000
# 3302  3474.400000  2907.500000  1121.000000  1458.833333  1844.000000
# 3303  3429.250000  3303.000000  1203.333333  1398.000000  1782.000000
# 3304  3502.583333  2949.750000  1238.000000  1582.000000  1866.666667
#
#                B5           B6           B7           B8          B8A  LC_Nr  \
# 0     1098.000000  1695.750000  1901.000000  2257.333333  2226.000000      7
# 1      952.666667  1618.800000  1868.500000  1861.500000  2135.000000      7
# 2     1156.250000  1856.625000  2145.750000  2619.000000  2523.500000      7
# 3     1056.000000  1666.000000  1925.000000  2076.000000  2252.000000      7
# 4     1241.500000  1904.416667  2156.500000  2371.600000  2507.500000      7
# ...           ...          ...          ...          ...          ...    ...
# 3300  1689.750000  1899.000000  2054.833333  2287.000000  2368.250000      3
# 3301  2052.250000  2444.166667  2571.083333  2662.666667  2812.333333      3
# 3302  2013.000000  2354.500000  2526.928571  2717.166667  2771.857143      3
# 3303  1736.000000  1926.000000  2068.000000  2502.000000  2315.000000      3
# 3304  2007.625000  2339.800000  2570.750000  2526.333333  2776.416667      3
#
#         LC_Out Landcover
# 0       Forest    Forest
# 1       Forest    Forest
# 2       Forest    Forest
# 3       Forest    Forest
# 4       Forest    Forest
# ...        ...       ...
# 3300  Built-up  Built up
# 3301  Built-up  Built up
# 3302  Built-up  Built up
# 3303  Built-up  Built up
# 3304  Built-up  Built up
#
# [3305 rows x 13 columns]

# %%
X_train = train.drop(['LC_Nr', 'LC_Out', 'Landcover'], axis=1)
X_train
# Out:
#               B11          B12           B2           B3           B4  \
# 0     2006.000000  1215.000000   522.100000   701.937500   810.666667
# 1     1903.000000  1237.500000   404.000000   529.000000   551.000000
# 2     2244.500000  1337.666667   476.500000   696.375000   735.000000
# 3     2029.000000  1238.000000   450.000000   622.000000   693.000000
# 4     2249.000000  1340.750000   498.000000   707.000000   797.500000
# ...           ...          ...          ...          ...          ...
# 3300  3092.666667  2532.000000   866.500000  1101.500000  1475.000000
# 3301  3588.000000  3187.500000  1151.000000  1325.000000  2030.700000
# 3302  3474.400000  2907.500000  1121.000000  1458.833333  1844.000000
# 3303  3429.250000  3303.000000  1203.333333  1398.000000  1782.000000
# 3304  3502.583333  2949.750000  1238.000000  1582.000000  1866.666667
#
#                B5           B6           B7           B8          B8A
# 0     1098.000000  1695.750000  1901.000000  2257.333333  2226.000000
# 1      952.666667  1618.800000  1868.500000  1861.500000  2135.000000
# 2     1156.250000  1856.625000  2145.750000  2619.000000  2523.500000
# 3     1056.000000  1666.000000  1925.000000  2076.000000  2252.000000
# 4     1241.500000  1904.416667  2156.500000  2371.600000  2507.500000
# ...           ...          ...          ...          ...          ...
# 3300  1689.750000  1899.000000  2054.833333  2287.000000  2368.250000
# 3301  2052.250000  2444.166667  2571.083333  2662.666667  2812.333333
# 3302  2013.000000  2354.500000  2526.928571  2717.166667  2771.857143
# 3303  1736.000000  1926.000000  2068.000000  2502.000000  2315.000000
# 3304  2007.625000  2339.800000  2570.750000  2526.333333  2776.416667
#
# [3305 rows x 10 columns]

# %%
y_train = train['LC_Nr']
y_train
# Out:
# 0       7
# 1       7
# 2       7
# 3       7
# 4       7
#        ..
# 3300    3
# 3301    3
# 3302    3
# 3303    3
# 3304    3
# Name: LC_Nr, Length: 3305, dtype: int64

# %%
test = pd.read_csv('data/test.csv')
test
# Out:
#                B11          B12           B2           B3           B4  \
# 0      1492.200000   754.666667   326.363636   454.545455   359.500000
# 1      1393.000000   654.000000   286.000000   404.000000   324.000000
# 2      1879.500000  1112.333333   387.750000   539.750000   563.666667
# 3      1854.666667  1055.000000   358.000000   486.600000   515.000000
# 4      2185.600000  1432.500000   491.800000   686.384615   810.200000
# ...            ...          ...          ...          ...          ...
# 78316  2933.750000  2918.666667   972.400000  1253.000000  1621.333333
# 78317  3748.500000  3796.857143  1192.666667  1412.000000  1753.000000
# 78318  3832.000000  3842.883333  1321.200000  1558.500000  1933.800000
# 78319  3834.500000  3540.500000  1269.000000  1395.000000  1776.000000
# 78320  3876.666667  3905.250000  1221.333333  1444.500000  1810.000000
#
#                 B5        B6           B7           B8          B8A  LC_Nr  \
# 0       741.000000  1498.500  1754.666667  1896.500000  1956.000000      7
# 1       656.000000  1472.000  1695.000000  1758.000000  1890.000000      7
# 2       967.500000  1588.750  1797.000000  1792.000000  2065.250000      7
# 3       882.333333  1581.000  1811.250000  1846.000000  2100.250000      7
# 4      1173.285714  1643.125  1868.714286  2091.500000  2164.222222      7
# ...            ...       ...          ...          ...          ...    ...
# 78316  1959.000000  2026.000  2106.166667  1894.000000  2159.750000      3
# 78317  2074.333333  2197.000  2339.500000  2432.000000  2625.000000      3
# 78318  2081.000000  2198.000  2375.333333  2643.000000  2629.500000      3
# 78319  1950.500000  2181.000  2431.500000  2635.000000  2786.500000      3
# 78320  2071.250000  2229.125  2389.000000  2477.333333  2659.500000      3
#
#          LC_Out Landcover
# 0        Forest    Forest
# 1        Forest    Forest
# 2        Forest    Forest
# 3        Forest    Forest
# 4        Forest    Forest
# ...         ...       ...
# 78316  Built-up  Built up
# 78317  Built-up  Built up
# 78318  Built-up  Built up
# 78319  Built-up  Built up
# 78320  Built-up  Built up
#
# [78321 rows x 13 columns]

# %%
X_test = test.drop(['LC_Nr', 'LC_Out', 'Landcover'], axis=1)
X_test
# Out:
#                B11          B12           B2           B3           B4  \
# 0      1492.200000   754.666667   326.363636   454.545455   359.500000
# 1      1393.000000   654.000000   286.000000   404.000000   324.000000
# 2      1879.500000  1112.333333   387.750000   539.750000   563.666667
# 3      1854.666667  1055.000000   358.000000   486.600000   515.000000
# 4      2185.600000  1432.500000   491.800000   686.384615   810.200000
# ...            ...          ...          ...          ...          ...
# 78316  2933.750000  2918.666667   972.400000  1253.000000  1621.333333
# 78317  3748.500000  3796.857143  1192.666667  1412.000000  1753.000000
# 78318  3832.000000  3842.883333  1321.200000  1558.500000  1933.800000
# 78319  3834.500000  3540.500000  1269.000000  1395.000000  1776.000000
# 78320  3876.666667  3905.250000  1221.333333  1444.500000  1810.000000
#
#                 B5        B6           B7           B8          B8A
# 0       741.000000  1498.500  1754.666667  1896.500000  1956.000000
# 1       656.000000  1472.000  1695.000000  1758.000000  1890.000000
# 2       967.500000  1588.750  1797.000000  1792.000000  2065.250000
# 3       882.333333  1581.000  1811.250000  1846.000000  2100.250000
# 4      1173.285714  1643.125  1868.714286  2091.500000  2164.222222
# ...            ...       ...          ...          ...          ...
# 78316  1959.000000  2026.000  2106.166667  1894.000000  2159.750000
# 78317  2074.333333  2197.000  2339.500000  2432.000000  2625.000000
# 78318  2081.000000  2198.000  2375.333333  2643.000000  2629.500000
# 78319  1950.500000  2181.000  2431.500000  2635.000000  2786.500000
# 78320  2071.250000  2229.125  2389.000000  2477.333333  2659.500000
#
# [78321 rows x 10 columns]

# %%
y_test = test['LC_Nr']
y_test
# Out:
# 0        7
# 1        7
# 2        7
# 3        7
# 4        7
#         ..
# 78316    3
# 78317    3
# 78318    3
# 78319    3
# 78320    3
# Name: LC_Nr, Length: 78321, dtype: int64

# %% [markdown]
# ## Use auto-sklearn to find the best model

# %%
automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=60*60,
    resampling_strategy='cv',
    resampling_strategy_arguments={'folds': 10},
    metric=autosklearn.metrics.f1_macro,
    n_jobs=-1,
    ensemble_kwargs = {'ensemble_size': 1},
    include = {
        'classifier': ['random_forest'],
        'feature_preprocessor': ['no_preprocessing']
    }
)

# %%
automl.fit(X_train, y_train)
# Out:
# AutoSklearnClassifier(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                       ensemble_kwargs={'ensemble_size': 1},
#                       include={'classifier': ['random_forest'],
#                                'feature_preprocessor': ['no_preprocessing']},
#                       metric=f1_macro, n_jobs=-1, per_run_time_limit=720,
#                       resampling_strategy='cv',
#                       resampling_strategy_arguments={'folds': 10})

# %%
y_train_pred = automl.predict(X_train)
y_test_pred = automl.predict(X_test)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Train set classification metrics

# %%
print('Accuracy: {:0.4f}'.format(accuracy_score(y_train, y_train_pred)))
# Out:
# Accuracy: 1.0000

# %%
print('Precision: {:0.4f}'.format(precision_score(y_train, y_train_pred, average='macro')))
# Out:
# Precision: 1.0000

# %%
print('Recall: {:0.4f}'.format(recall_score(y_train, y_train_pred, average='macro')))
# Out:
# Recall: 1.0000

# %%
print('F1-Score: {:0.4f}'.format(f1_score(y_train, y_train_pred, average='macro')))
# Out:
# F1-Score: 1.0000

# %%
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       263
#            2       1.00      1.00      1.00       332
#            3       1.00      1.00      1.00       210
#            4       1.00      1.00      1.00       500
#            5       1.00      1.00      1.00       500
#            6       1.00      1.00      1.00       500
#            7       1.00      1.00      1.00       500
#            8       1.00      1.00      1.00       500
#
#     accuracy                           1.00      3305
#    macro avg       1.00      1.00      1.00      3305
# weighted avg       1.00      1.00      1.00      3305

# %%
cm = confusion_matrix(y_train, y_train_pred)
cm
# Out:
# array([[263,   0,   0,   0,   0,   0,   0,   0],
#        [  0, 332,   0,   0,   0,   0,   0,   0],
#        [  0,   0, 210,   0,   0,   0,   0,   0],
#        [  0,   0,   0, 500,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 500,   0,   0,   0],
#        [  0,   0,   0,   0,   0, 500,   0,   0],
#        [  0,   0,   0,   0,   0,   0, 500,   0],
#        [  0,   0,   0,   0,   0,   0,   0, 500]])

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.show()

# %% [markdown]
# ### Test set classifiction metrics

# %%
print('Accuracy: {:0.4f}'.format(accuracy_score(y_test, y_test_pred)))
# Out:
# Accuracy: 0.8515

# %%
print('Precision: {:0.4f}'.format(precision_score(y_test, y_test_pred, average='macro')))
# Out:
# Precision: 0.7016

# %%
print('Recall: {:0.4f}'.format(recall_score(y_test, y_test_pred, average='macro')))
# Out:
# Recall: 0.8502

# %%
print('F1-Score: {:0.4f}'.format(f1_score(y_test, y_test_pred, average='macro')))
# Out:
# F1-Score: 0.7316

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.88      0.99      0.93       113
#            2       0.10      0.83      0.18       143
#            3       0.70      0.84      0.76        90
#            4       0.98      0.88      0.93     17628
#            5       0.52      0.79      0.63      3248
#            6       0.54      0.79      0.64      8266
#            7       0.95      0.87      0.91     35183
#            8       0.95      0.81      0.87     13650
#
#     accuracy                           0.85     78321
#    macro avg       0.70      0.85      0.73     78321
# weighted avg       0.89      0.85      0.87     78321

# %%
cm = confusion_matrix(y_test, y_test_pred)
cm
# Out:
# array([[  112,     0,     0,     0,     0,     0,     0,     1],
#        [    0,   118,     2,    19,     3,     1,     0,     0],
#        [    0,     8,    76,     4,     1,     1,     0,     0],
#        [    0,   961,    31, 15520,   622,   338,   135,    21],
#        [    0,    23,     0,    46,  2570,   300,    11,   298],
#        [    0,    48,     0,   109,   369,  6505,  1125,   110],
#        [    0,     0,     0,    12,    11,  4179, 30772,   209],
#        [   15,     1,     0,   111,  1384,   802,   318, 11019]])

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.show()

# %% [markdown]
# ### Model ranking and hyperparameters

# %%
automl.leaderboard(detailed=True, ensemble_only=False)
# Out:
#           rank  ensemble_weight           type      cost    duration  \
# model_id
# 3            1              1.0  random_forest  0.141789  181.473844
# 58           2              0.0  random_forest  0.143692  109.697581
# 62           3              0.0  random_forest  0.146993  168.055988
# 48           4              0.0  random_forest  0.147495   71.370099
# 2            5              0.0  random_forest  0.150459  110.215751
# 13           6              0.0  random_forest  0.150780   71.971038
# 18           8              0.0  random_forest  0.154294  145.646889
# 27           7              0.0  random_forest  0.154294  133.580346
# 40           9              0.0  random_forest  0.154471  114.785823
# 28          10              0.0  random_forest  0.155193  138.677424
# 12          11              0.0  random_forest  0.155595  137.812458
# 19          12              0.0  random_forest  0.155620  115.545765
# 21          13              0.0  random_forest  0.155620  115.756606
# 43          14              0.0  random_forest  0.157569   86.889251
# 60          15              0.0  random_forest  0.161922  174.001529
# 41          16              0.0  random_forest  0.162054   79.451033
# 24          17              0.0  random_forest  0.163506  352.213042
# 52          18              0.0  random_forest  0.166970  123.347558
# 33          19              0.0  random_forest  0.169327  118.717304
# 11          20              0.0  random_forest  0.170711   73.007297
# 15          21              0.0  random_forest  0.171220  153.030565
# 32          22              0.0  random_forest  0.179622  135.690214
# 7           23              0.0  random_forest  0.179913  140.781191
# 38          24              0.0  random_forest  0.181224   89.731349
# 36          25              0.0  random_forest  0.185130  114.880952
# 45          26              0.0  random_forest  0.185695  211.685308
# 6           27              0.0  random_forest  0.186500  117.655305
# 30          28              0.0  random_forest  0.187331   87.837491
# 54          29              0.0  random_forest  0.190682  182.248584
# 5           30              0.0  random_forest  0.191480  151.980103
# 44          31              0.0  random_forest  0.191672  117.678470
# 16          32              0.0  random_forest  0.192889   97.025208
# 46          33              0.0  random_forest  0.193427   55.031943
# 42          34              0.0  random_forest  0.193440  202.768899
# 14          35              0.0  random_forest  0.193624   99.961965
# 31          36              0.0  random_forest  0.193667  160.897171
# 4           37              0.0  random_forest  0.197756  151.467146
# 29          38              0.0  random_forest  0.198647   58.531838
# 50          39              0.0  random_forest  0.201538   65.831436
# 17          40              0.0  random_forest  0.201565  118.984581
# 56          41              0.0  random_forest  0.202074  110.029685
# 59          42              0.0  random_forest  0.202236   60.267809
# 49          43              0.0  random_forest  0.203768   88.500723
# 51          44              0.0  random_forest  0.204215  171.706125
# 9           45              0.0  random_forest  0.204778  103.702808
# 10          46              0.0  random_forest  0.213064  176.071722
# 26          47              0.0  random_forest  0.215827  216.876407
# 47          48              0.0  random_forest  0.225181   62.089132
# 8           49              0.0  random_forest  0.249147   59.095394
# 39          50              0.0  random_forest  0.249251   92.700219
# 37          51              0.0  random_forest  0.263851   70.761230
# 55          52              0.0  random_forest  0.266805   66.647387
# 53          53              0.0  random_forest  0.269623  271.873494
#
#           config_id  train_loss  seed    start_time      end_time  budget  \
# model_id
# 3                 2    0.000000     0  1.710015e+09  1.710015e+09     0.0
# 58               57    0.000000     0  1.710018e+09  1.710018e+09     0.0
# 62               61    0.001420     0  1.710018e+09  1.710018e+09     0.0
# 48               47    0.000000     0  1.710017e+09  1.710017e+09     0.0
# 2                 1    0.000000     0  1.710015e+09  1.710015e+09     0.0
# 13               12    0.000250     0  1.710015e+09  1.710015e+09     0.0
# 18               17    0.007070     0  1.710016e+09  1.710016e+09     0.0
# 27               26    0.007070     0  1.710016e+09  1.710016e+09     0.0
# 40               39    0.002633     0  1.710017e+09  1.710017e+09     0.0
# 28               27    0.006306     0  1.710016e+09  1.710016e+09     0.0
# 12               11    0.011311     0  1.710015e+09  1.710015e+09     0.0
# 19               18    0.009138     0  1.710016e+09  1.710016e+09     0.0
# 21               20    0.009138     0  1.710016e+09  1.710016e+09     0.0
# 43               42    0.013442     0  1.710017e+09  1.710017e+09     0.0
# 60               59    0.023833     0  1.710018e+09  1.710018e+09     0.0
# 41               40    0.014732     0  1.710017e+09  1.710017e+09     0.0
# 24               23    0.019979     0  1.710016e+09  1.710016e+09     0.0
# 52               51    0.031652     0  1.710017e+09  1.710017e+09     0.0
# 33               32    0.054574     0  1.710016e+09  1.710017e+09     0.0
# 11               10    0.041464     0  1.710015e+09  1.710015e+09     0.0
# 15               14    0.039828     0  1.710015e+09  1.710016e+09     0.0
# 32               31    0.100478     0  1.710016e+09  1.710016e+09     0.0
# 7                 6    0.092351     0  1.710015e+09  1.710015e+09     0.0
# 38               37    0.078439     0  1.710017e+09  1.710017e+09     0.0
# 36               35    0.091373     0  1.710016e+09  1.710017e+09     0.0
# 45               44    0.105226     0  1.710017e+09  1.710017e+09     0.0
# 6                 5    0.098973     0  1.710015e+09  1.710015e+09     0.0
# 30               29    0.082335     0  1.710016e+09  1.710016e+09     0.0
# 54               53    0.122255     0  1.710017e+09  1.710018e+09     0.0
# 5                 4    0.118513     0  1.710015e+09  1.710015e+09     0.0
# 44               43    0.141604     0  1.710017e+09  1.710017e+09     0.0
# 16               15    0.000000     0  1.710015e+09  1.710016e+09     0.0
# 46               45    0.114680     0  1.710017e+09  1.710017e+09     0.0
# 42               41    0.000000     0  1.710017e+09  1.710017e+09     0.0
# 14               13    0.125807     0  1.710015e+09  1.710015e+09     0.0
# 31               30    0.000028     0  1.710016e+09  1.710016e+09     0.0
# 4                 3    0.141033     0  1.710015e+09  1.710015e+09     0.0
# 29               28    0.132411     0  1.710016e+09  1.710016e+09     0.0
# 50               49    0.135841     0  1.710017e+09  1.710017e+09     0.0
# 17               16    0.138943     0  1.710016e+09  1.710016e+09     0.0
# 56               55    0.018443     0  1.710018e+09  1.710018e+09     0.0
# 59               58    0.149262     0  1.710018e+09  1.710018e+09     0.0
# 49               48    0.170628     0  1.710017e+09  1.710017e+09     0.0
# 51               50    0.152849     0  1.710017e+09  1.710017e+09     0.0
# 9                 8    0.162843     0  1.710015e+09  1.710015e+09     0.0
# 10                9    0.056494     0  1.710015e+09  1.710015e+09     0.0
# 26               25    0.146557     0  1.710016e+09  1.710016e+09     0.0
# 47               46    0.079903     0  1.710017e+09  1.710017e+09     0.0
# 8                 7    0.176826     0  1.710015e+09  1.710015e+09     0.0
# 39               38    0.170513     0  1.710017e+09  1.710017e+09     0.0
# 37               36    0.210125     0  1.710017e+09  1.710017e+09     0.0
# 55               54    0.216708     0  1.710018e+09  1.710018e+09     0.0
# 53               52    0.176841     0  1.710017e+09  1.710018e+09     0.0
#
#                       status data_preprocessors feature_preprocessors  \
# model_id
# 3         StatusType.SUCCESS                 []    [no_preprocessing]
# 58        StatusType.SUCCESS                 []    [no_preprocessing]
# 62        StatusType.SUCCESS                 []    [no_preprocessing]
# 48        StatusType.SUCCESS                 []    [no_preprocessing]
# 2         StatusType.SUCCESS                 []    [no_preprocessing]
# 13        StatusType.SUCCESS                 []    [no_preprocessing]
# 18        StatusType.SUCCESS                 []    [no_preprocessing]
# 27        StatusType.SUCCESS                 []    [no_preprocessing]
# 40        StatusType.SUCCESS                 []    [no_preprocessing]
# 28        StatusType.SUCCESS                 []    [no_preprocessing]
# 12        StatusType.SUCCESS                 []    [no_preprocessing]
# 19        StatusType.SUCCESS                 []    [no_preprocessing]
# 21        StatusType.SUCCESS                 []    [no_preprocessing]
# 43        StatusType.SUCCESS                 []    [no_preprocessing]
# 60        StatusType.SUCCESS                 []    [no_preprocessing]
# 41        StatusType.SUCCESS                 []    [no_preprocessing]
# 24        StatusType.SUCCESS                 []    [no_preprocessing]
# 52        StatusType.SUCCESS                 []    [no_preprocessing]
# 33        StatusType.SUCCESS                 []    [no_preprocessing]
# 11        StatusType.SUCCESS                 []    [no_preprocessing]
# 15        StatusType.SUCCESS                 []    [no_preprocessing]
# 32        StatusType.SUCCESS                 []    [no_preprocessing]
# 7         StatusType.SUCCESS                 []    [no_preprocessing]
# 38        StatusType.SUCCESS                 []    [no_preprocessing]
# 36        StatusType.SUCCESS                 []    [no_preprocessing]
# 45        StatusType.SUCCESS                 []    [no_preprocessing]
# 6         StatusType.SUCCESS                 []    [no_preprocessing]
# 30        StatusType.SUCCESS                 []    [no_preprocessing]
# 54        StatusType.SUCCESS                 []    [no_preprocessing]
# 5         StatusType.SUCCESS                 []    [no_preprocessing]
# 44        StatusType.SUCCESS                 []    [no_preprocessing]
# 16        StatusType.SUCCESS                 []    [no_preprocessing]
# 46        StatusType.SUCCESS                 []    [no_preprocessing]
# 42        StatusType.SUCCESS                 []    [no_preprocessing]
# 14        StatusType.SUCCESS                 []    [no_preprocessing]
# 31        StatusType.SUCCESS                 []    [no_preprocessing]
# 4         StatusType.SUCCESS                 []    [no_preprocessing]
# 29        StatusType.SUCCESS                 []    [no_preprocessing]
# 50        StatusType.SUCCESS                 []    [no_preprocessing]
# 17        StatusType.SUCCESS                 []    [no_preprocessing]
# 56        StatusType.SUCCESS                 []    [no_preprocessing]
# 59        StatusType.SUCCESS                 []    [no_preprocessing]
# 49        StatusType.SUCCESS                 []    [no_preprocessing]
# 51        StatusType.SUCCESS                 []    [no_preprocessing]
# 9         StatusType.SUCCESS                 []    [no_preprocessing]
# 10        StatusType.SUCCESS                 []    [no_preprocessing]
# 26        StatusType.SUCCESS                 []    [no_preprocessing]
# 47        StatusType.SUCCESS                 []    [no_preprocessing]
# 8         StatusType.SUCCESS                 []    [no_preprocessing]
# 39        StatusType.SUCCESS                 []    [no_preprocessing]
# 37        StatusType.SUCCESS                 []    [no_preprocessing]
# 55        StatusType.SUCCESS                 []    [no_preprocessing]
# 53        StatusType.SUCCESS                 []    [no_preprocessing]
#
#          balancing_strategy           config_origin
# model_id
# 3                 weighting          Initial design
# 58                     none            Local Search
# 62                weighting            Local Search
# 48                     none            Local Search
# 2                      none          Initial design
# 13                     none  Random Search (sorted)
# 18                weighting  Random Search (sorted)
# 27                weighting            Local Search
# 40                     none           Random Search
# 28                     none  Random Search (sorted)
# 12                weighting           Random Search
# 19                weighting  Random Search (sorted)
# 21                weighting            Local Search
# 43                weighting            Local Search
# 60                weighting           Random Search
# 41                weighting  Random Search (sorted)
# 24                weighting           Random Search
# 52                     none           Random Search
# 33                     none            Local Search
# 11                     none  Random Search (sorted)
# 15                     none           Random Search
# 32                weighting           Random Search
# 7                 weighting           Random Search
# 38                     none           Random Search
# 36                weighting            Local Search
# 45                weighting           Random Search
# 6                 weighting  Random Search (sorted)
# 30                     none           Random Search
# 54                weighting            Local Search
# 5                 weighting  Random Search (sorted)
# 44                     none           Random Search
# 16                weighting  Random Search (sorted)
# 46                weighting  Random Search (sorted)
# 42                weighting           Random Search
# 14                     none           Random Search
# 31                weighting            Local Search
# 4                 weighting          Initial design
# 29                     none           Random Search
# 50                weighting           Random Search
# 17                weighting           Random Search
# 56                     none           Random Search
# 59                     none           Random Search
# 49                     none           Random Search
# 51                weighting           Random Search
# 9                      none           Random Search
# 10                weighting  Random Search (sorted)
# 26                weighting           Random Search
# 47                weighting  Random Search (sorted)
# 8                 weighting           Random Search
# 39                     none           Random Search
# 37                weighting           Random Search
# 55                     none           Random Search
# 53                weighting           Random Search

# %%
automl.get_models_with_weights()
# Out:
# [(1.0,
#   SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'classifier:__choice__': 'random_forest', 'data_preprocessor:__choice__': 'feature_type', 'feature_preprocessor:__choice__': 'no_preprocessing', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.41808321658160696, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 4, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'data_preprocessor:feature_type:numerical_transformer:imputation:strategy': 'median', 'data_preprocessor:feature_type:numerical_transformer:rescaling:__choice__': 'standardize'},
#   dataset_properties={
#     'task': 2,
#     'sparse': False,
#     'multilabel': False,
#     'multiclass': True,
#     'target_type': 'classification',
#     'signed': False}))]

# %%
automl.show_models()
# Out:
# {3: {'model_id': 3,
#   'rank': 1,
#   'cost': 0.1417888840125893,
#   'ensemble_weight': 1.0,
#   'voting_model': VotingClassifier(estimators=None, voting='soft'),
#   'estimators': [{'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb922d72b0>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb7c1a33a0>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb7c1a1b70>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)},
#    {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb7c1d6770>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb7c1d5900>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb7c1d4d90>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)},
#    {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb8da8cac0>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb7b761a20>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb7b762e00>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)},
#    {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb8ef72d10>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb8edf8790>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb8edf8850>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)},
#    {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb8ec3c400>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb8ec3de40>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb8ec3df00>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)},
#    {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb78b95ab0>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb78b974f0>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb78b975b0>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)},
#    {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb78803130>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb78880bb0>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb78880c70>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)},
#    {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb786a4850>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb786a6290>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb786a6350>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)},
#    {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb77b05ed0>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb77b07910>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb77b079d0>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)},
#    {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice at 0x79fb7797b5b0>,
#     'balancing': Balancing(random_state=1, strategy='weighting'),
#     'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice at 0x79fb779f5030>,
#     'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice at 0x79fb779f50f0>,
#     'sklearn_classifier': RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=2,
#                            min_samples_split=4, n_estimators=512, n_jobs=1,
#                            random_state=1, warm_start=True)}]}}
