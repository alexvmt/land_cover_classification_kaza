# %% [markdown]
# # Collect Sentinel-2 data
#
# - using the labels provided by Nuno (Binga)
# - the labels are there but the actual band values need to be collected using this notebook

# %%
from google.colab import drive
import ee
import numpy as np
import pandas as pd
import geopandas as gpd
import geemap
import time

# %% [markdown]
# ## Setup

# %%
drive.mount('/content/drive')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/land_cover_classification_kaza/automl
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /content/drive/MyDrive/land_cover_classification_kaza/automl

# %%
ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Initialize(project='ee-alexvmt')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Load and clean labels

# %%
file_name = 'RND_Binga_1000'
gdf = gpd.read_file('{}.shp'.format(file_name))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        id  LC2023 LC2022 LC2021 LC2020 Comments  LC2023_Num  LC2023_N2  \
# 0     0.0   Shrub   None   None   None     None         5.0        5.0
# 1     1.0  Forest   None   None   None     None         3.0        3.0
# 2     2.0    Crop   None   None   None     None         2.0        2.0
# 3     3.0   Shrub   None   None   None     None         5.0        5.0
# 4     4.0  Forest   None   None   None     None         3.0        3.0
# ...   ...     ...    ...    ...    ...      ...         ...        ...
# 1260  NaN    Crop   None   None   None     None         NaN        NaN
# 1261  NaN    Crop   None   None   None     None         NaN        NaN
# 1262  NaN    Crop   None   None   None     None         NaN        NaN
# 1263  NaN    Crop   None   None   None     None         NaN        NaN
# 1264  NaN    Crop   None   None   None     None         NaN        NaN
#
#                         geometry
# 0     POINT (27.77476 -17.22082)
# 1     POINT (27.80260 -18.07115)
# 2     POINT (28.06489 -17.48651)
# 3     POINT (27.68538 -17.65882)
# 4     POINT (27.21559 -18.16223)
# ...                          ...
# 1260  POINT (27.36553 -17.73099)
# 1261  POINT (27.35226 -17.73310)
# 1262  POINT (27.36824 -17.72848)
# 1263  POINT (27.39716 -17.69348)
# 1264  POINT (27.39873 -17.68851)
#
# [1265 rows x 9 columns]

# %%
gdf[gdf['LC2023'].isnull() | gdf['geometry'].isnull()]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        id     LC2023 LC2022 LC2021 LC2020 Comments  LC2023_Num  LC2023_N2  \
# 1000  0.0  Grassland   None   None   None     None         4.0        4.0
# 1239  NaN       None   Crop   None   None     None         NaN        NaN
#
#                         geometry
# 1000                        None
# 1239  POINT (27.45679 -17.69189)

# %%
gdf.shape
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# (1265, 9)

# %%
gdf = gdf[gdf['LC2023'].notnull() & gdf['geometry'].notnull()].reset_index(drop=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
gdf.shape
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# (1263, 9)

# %%
gdf['LC2023'].value_counts()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Forest       317
# Shrub        304
# Crop         223
# Water        113
# BuiltUp      105
# Grassland     77
# Wetlands      65
# Bare          59
# Name: LC2023, dtype: int64

# %%
land_cover_classes = list(gdf['LC2023'].unique())
land_cover_classes.sort()
land_cover_classes
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['Bare',
#  'BuiltUp',
#  'Crop',
#  'Forest',
#  'Grassland',
#  'Shrub',
#  'Water',
#  'Wetlands']

# %%
classes_dict = {'Bare': 0,
                'BuiltUp': 1,
                'Crop': 2,
                'Forest': 3,
                'Grassland': 4,
                'Shrub': 5,
                'Water': 6,
                'Wetlands': 7}

# %%
gdf['class'] = gdf['LC2023'].map(classes_dict)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        id  LC2023 LC2022 LC2021 LC2020 Comments  LC2023_Num  LC2023_N2  \
# 0     0.0   Shrub   None   None   None     None         5.0        5.0
# 1     1.0  Forest   None   None   None     None         3.0        3.0
# 2     2.0    Crop   None   None   None     None         2.0        2.0
# 3     3.0   Shrub   None   None   None     None         5.0        5.0
# 4     4.0  Forest   None   None   None     None         3.0        3.0
# ...   ...     ...    ...    ...    ...      ...         ...        ...
# 1258  NaN    Crop   None   None   None     None         NaN        NaN
# 1259  NaN    Crop   None   None   None     None         NaN        NaN
# 1260  NaN    Crop   None   None   None     None         NaN        NaN
# 1261  NaN    Crop   None   None   None     None         NaN        NaN
# 1262  NaN    Crop   None   None   None     None         NaN        NaN
#
#                         geometry  class
# 0     POINT (27.77476 -17.22082)      5
# 1     POINT (27.80260 -18.07115)      3
# 2     POINT (28.06489 -17.48651)      2
# 3     POINT (27.68538 -17.65882)      5
# 4     POINT (27.21559 -18.16223)      3
# ...                          ...    ...
# 1258  POINT (27.36553 -17.73099)      2
# 1259  POINT (27.35226 -17.73310)      2
# 1260  POINT (27.36824 -17.72848)      2
# 1261  POINT (27.39716 -17.69348)      2
# 1262  POINT (27.39873 -17.68851)      2
#
# [1263 rows x 10 columns]

# %% [markdown]
# ## Load and prepare Sentinel-2 data

# %%
start_date = '2023-01-01'
end_date = '2023-12-31'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
bands = ['B2',
         'B3',
         'B4',
         'B5',
         'B6',
         'B7',
         'B8',
         'B8A',
         'B11',
         'B12']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# filter to less cloudy images? -> 20%
# mask clouds?
# median composite for rainy and dry season
# rainy season: November to March/April
s2 = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED').filterDate(ee.Date(start_date), ee.Date(end_date)).select(bands).median()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Collect and export data

# %%
def get_band_values_from_points(columns, gdf, image, chunks):

  df_with_bands = pd.DataFrame(columns=columns)

  list_gdf = np.array_split(gdf, chunks)

  for i, gdf in enumerate(list_gdf):
    print('Processing chunk {}/{}...'.format(i+1, chunks))
    fc = geemap.geopandas_to_ee(gdf)
    fc_with_bands = image.sampleRegions(collection=fc, scale=10)
    df_with_bands_temp = geemap.ee_to_pandas(fc_with_bands)
    df_with_bands = pd.concat([df_with_bands, df_with_bands_temp])

  df_with_bands = df_with_bands.reset_index(drop=True)

  return(df_with_bands)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
columns = bands + ['class'] + ['LC2023']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
start_time = time.perf_counter()
df_with_bands = get_band_values_from_points(columns, gdf, s2, 10)
end_time = time.perf_counter()
run_time = round((end_time - start_time) / 60, 2)
print('Run time: {} minutes.'.format(run_time))

# %%
df_with_bands = df_with_bands[columns]
df_with_bands
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                B2           B3           B4           B5           B6  \
# 0      542.294118   686.076923   869.000000  1314.500000  1749.250000
# 1      566.842105   808.500000  1061.200000  1638.714286  2009.000000
# 2     1250.285714  1635.000000  2214.000000  2658.333333  2989.333333
# 3      673.200000   861.000000  1196.000000  1561.400000  1857.892857
# 4      795.500000   991.000000  1188.125000  1569.285714  2205.368421
# ...           ...          ...          ...          ...          ...
# 1258   921.880000  1497.058824  2719.764706  3164.312500  3425.750000
# 1259   795.681818  1210.539130  2206.444444  2655.533333  2907.400000
# 1260   854.928571  1364.608696  2593.454545  3039.000000  3304.100000
# 1261   796.954545  1239.200000  2445.200000  2837.000000  2992.666667
# 1262   913.416667  1420.750000  2545.111111  2957.615385  3181.000000
#
#                B7           B8          B8A          B11          B12 class  \
# 0     1914.444444  1948.250000  2277.333333  2616.000000  1867.000000     5
# 1     2412.250000  2648.750000  2837.666667  3107.000000  1995.800000     3
# 2     3210.000000  3216.000000  3572.000000  4027.000000  2747.000000     2
# 3     2120.166667  2334.400000  2563.433333  2975.250000  2087.666667     5
# 4     2464.100000  2594.357143  2784.600000  2832.400000  2037.833333     3
# ...           ...          ...          ...          ...          ...   ...
# 1258  3591.891667  3683.636364  3777.244444  5072.571429  4572.187500     2
# 1259  3107.285714  3170.500000  3291.800000  4558.333333  3892.666667     2
# 1260  3490.909091  3549.142857  3736.571429  4980.000000  4364.250000     2
# 1261  3182.000000  3275.200000  3427.000000  4977.400000  4601.750000     2
# 1262  3407.666667  3596.000000  3701.600000  4844.750000  4207.000000     2
#
#       LC2023
# 0      Shrub
# 1     Forest
# 2       Crop
# 3      Shrub
# 4     Forest
# ...      ...
# 1258    Crop
# 1259    Crop
# 1260    Crop
# 1261    Crop
# 1262    Crop
#
# [1263 rows x 12 columns]

# %%
df_with_bands.to_csv('{}.csv'.format(file_name), index=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
